# %% [markdown]
# # HBV hydrological model forced with ERA5 forcing data
# In this notebook we will generate forcing data for the HBV hydrological model from the ERA5 dataset and from a historical CMIP dataset (ie output of a climate model when run for a period of time that represents part of history, not a future prediction).
#
# We use the forcing module of the eWaterCycle platform to easily generate this data.
#
# Later on this forcing will be used to both calibrate and run the HBV hydrological model and produce estimates of river discharge.

# %%
# General python
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

import numpy as np
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import xarray as xr
import json
from esmvalcore.config import CFG
import shutil
import sys
import geopandas as gpd
import rioxarray

# Niceties
from rich import print

# This will work normally for HPC
try:
    from scripts.forcing_destine import DestinEHistoricalForcing
except ImportError:
    # Add the project root to Python path for use on SRC
    project_root = Path().resolve().parent
    sys.path.append(str(project_root))

    from scripts.forcing_destine import DestinEHistoricalForcing

import earthkit.data
import earthkit.regrid
from dask.diagnostics import ProgressBar
from datetime import datetime

# %%
# General eWaterCycle
import ewatercycle
import ewatercycle.forcing

# %%
# Parameters, these get changed when running on HPC
country = "australia"
region_id = "camelsaus_102101A"
settings_path = "settings.json"

# %%
# Load settings
# Read from the JSON file
with open(settings_path, "r") as json_file:
    settings = json.load(json_file)

# %%
display(settings)
# Out:
# {'caravan_id': 'camelsaus_102101A',
#  'country': 'australia',
#  'calibration_start_date': '1994-08-01T00:00:00Z',
#  'calibration_end_date': '2004-07-31T00:00:00Z',
#  'validation_start_date': '2004-08-01T00:00:00Z',
#  'validation_end_date': '2014-07-31T00:00:00Z',
#  'future_start_date': '2029-08-01T00:00:00Z',
#  'future_end_date': '2039-08-31T00:00:00Z',
#  'CMIP_info': {'dataset': ['MPI-ESM1-2-LR'],
#   'ensembles': ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1'],
#   'experiments': ['historical', 'ssp126', 'ssp245', 'ssp370', 'ssp585'],
#   'project': 'CMIP6',
#   'grid': 'gn'},
#  'base_path': '/home/mmelotto/ewatercycleClimateImpact/HBV',
#  'path_caravan': '/home/mmelotto/ewatercycleClimateImpact/HBV/forcing_data/australia/camelsaus_102101A/caravan',
#  'path_ERA5': '/home/mmelotto/ewatercycleClimateImpact/HBV/forcing_data/australia/camelsaus_102101A/ERA5',
#  'path_DestinE': '/home/mmelotto/ewatercycleClimateImpact/HBV/forcing_data/australia/camelsaus_102101A/DestinE',
#  'path_CMIP6': '/home/mmelotto/ewatercycleClimateImpact/HBV/forcing_data/australia/camelsaus_102101A/CMIP6',
#  'path_output': '/home/mmelotto/ewatercycleClimateImpact/HBV/output_data/australia/camelsaus_102101A',
#  'path_shape': '/home/mmelotto/ewatercycleClimateImpact/HBV/forcing_data/australia/camelsaus_102101A/caravan/camelsaus_102101A.shp',
#  'downloads': '/home/mmelotto/ewatercycleClimateImpact/HBV/downloads/camelsaus_102101A'}

# %% [markdown]
# ## Generate or load forcing
# When generating forcing using eWaterCycle there are two important choices to make: dataset that the data comes from and type of forcing that the model requires. The dataset in this example is ERA5. The HBV model in eWaterCycle needs potential evaporation data. Both the 'caravan' type forcing as well as the 'LumpedMakkinkForcing' provide potential evaporation. Note that the 'caravan' type forcing only works with the 'caravan' dataset as well, so here we select 'ERA5 for the dataset and LumpedMakkinkForcing for the type.
#
# Note that ERA5 data needs to be stored on the system you are working on. For SURF Research Cloud machines running the eWaterCycle catalog item, this is handled by the eWaterCycle team.
#
# More complex models often require their own type of forcing, for example the wflow model requires 'wflow' type forcing specifically designed for that model, but this is not the case for HBV in eWaterCycle.

# %%
# Generate forcing:
try:
    load_location = Path(settings['path_ERA5']) / "work" / "diagnostic" / "script" 
    ERA5_forcing_object = ewatercycle.forcing.sources["LumpedMakkinkForcing"].load(directory=load_location)
except:    
    ERA5_forcing_object = ewatercycle.forcing.sources["LumpedMakkinkForcing"].generate(
       dataset="ERA5",
       start_time=settings['calibration_start_date'],
       end_time=settings['validation_end_date'],
       directory=settings['path_ERA5'],
       shape=settings['path_shape'],
    )
# Out:
# ERROR:esmvalcore.preprocessor:Failed to run preprocessor function 'concatenate' on the data
# [<iris 'Cube' of precipitation_flux / (kg m-2 s-1) (time: 365; latitude: 721; longitude: 1440)>,
#  <iris 'Cube' of precipitation_flux / (kg m-2 s-1) (time: 365; latitude: 721; longitude: 1440)>,
#  <iris 'Cube' of precipitation_flux / (kg m-2 s-1) (time: 366; latitude: 721; longitude: 1440)>,
#  <iris 'Cube' of precipitation_flux / (kg m-2 s-1) (time: 365; latitude: 721; longitude: 1440)>]
# (and 17 further argument(s) not shown here; refer to the debug log for a full list)
# loaded from original input file(s)
# [LocalFile('/data/shared/climate-data/obs6/Tier3/ERA5/OBS6_ERA5_reanaly_1_day_pr_1994-1994.nc'),
#  LocalFile('/data/shared/climate-data/obs6/Tier3/ERA5/OBS6_ERA5_reanaly_1_day_pr_1995-1995.nc'),
#  LocalFile('/data/shared/climate-data/obs6/Tier3/ERA5/OBS6_ERA5_reanaly_1_day_pr_1996-1996.nc'),
#  LocalFile('/data/shared/climate-data/obs6/Tier3/ERA5/OBS6_ERA5_reanaly_1_day_pr_1997-1997.nc')]
# (and 17 further file(s) not shown here; refer to the debug log for a full list)
# with function argument(s)
# check_level = <CheckLevels.DEFAULT: 3>
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/tmp/ipykernel_95894/2963463459.py", line 4, in <module>
#     ERA5_forcing_object = ewatercycle.forcing.sources["LumpedMakkinkForcing"].load(directory=load_location)
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/ewatercycle/base/forcing.py", line 276, in load
#     raise FileNotFoundError(msg)
# FileNotFoundError: Forcing file /home/mmelotto/ewatercycleClimateImpact/HBV/forcing_data/australia/camelsaus_102101A/ERA5/work/diagnostic/script/ewatercycle_forcing.yaml not found. Perhaps you want to use LumpedMakkinkForcing(...)?
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/multiprocessing/pool.py", line 125, in worker
#     result = (True, func(*args, **kwds))
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/_task.py", line 816, in _run_task
#     output_files = task.run()
#                    ^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/_task.py", line 264, in run
#     self.output_files = self._run(input_files)
#                         ^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/preprocessor/__init__.py", line 684, in _run
#     product.apply(step, self.debug)
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/preprocessor/__init__.py", line 492, in apply
#     self.cubes = preprocess(self.cubes, step,
#                             ^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/preprocessor/__init__.py", line 502, in cubes
#     self._cubes = [ds.load() for ds in self.datasets]
#                    ^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/dataset.py", line 685, in load
#     cube = self._load()
#            ^^^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/dataset.py", line 771, in _load
#     result = preprocess(
#              ^^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/preprocessor/__init__.py", line 397, in preprocess
#     result.append(_run_preproc_function(function, items, settings,
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/preprocessor/__init__.py", line 346, in _run_preproc_function
#     return function(items, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/preprocessor/_io.py", line 336, in concatenate
#     _fix_calendars(cubes)
#   File "/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/preprocessor/_io.py", line 265, in _fix_calendars
#     calendar_index = int(
#                      ^^^^
# TypeError: only 0-dimensional arrays can be converted to Python scalars
# """
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 6
#       4     ERA5_forcing_object = ewatercycle.forcing.sources["LumpedMakkinkForcing"].load(directory=load_location)
#       5 except:
# ----> 6     ERA5_forcing_object = ewatercycle.forcing.sources["LumpedMakkinkForcing"].generate(
#       7        dataset="ERA5",
#       8        start_time=settings['calibration_start_date'],
#       9        end_time=settings['validation_end_date'],
#      10        directory=settings['path_ERA5'],
#      11        shape=settings['path_shape'],
#      12     )
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/ewatercycle/_forcings/makkink.py:57, in Makkink.generate(cls, dataset, start_time, end_time, shape, directory, **model_specific_options)
#      47 @classmethod
#      48 def generate(  # type: ignore[override]
#      49     cls: type["Makkink"],
#    (...)
#      55     **model_specific_options,
#      56 ) -> "Makkink":
# ---> 57     return super().generate(
#      58         dataset,
#      59         start_time,
#      60         end_time,
#      61         shape,
#      62         directory,
#      63         variables=("pr", "tas", "rsds"),
#      64         postprocessor=derive_e_pot,
#      65         **model_specific_options,
#      66     )
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/ewatercycle/base/forcing.py:162, in DefaultForcing.generate(cls, dataset, start_time, end_time, shape, directory, variables, postprocessor, **model_specific_options)
#     129 """Generate forcings for a model.
#     130
#     131 The forcing is generated with help of
#    (...)
#     151     model_specific_options: Subclass specific options.
#     152 """
#     153 recipe = cls._build_recipe(
#     154     dataset=dataset,
#     155     start_time=get_time(start_time),
#    (...)
#     159     **model_specific_options,
#     160 )
# --> 162 recipe_output = cls._run_recipe(
#     163     recipe, directory=Path(directory) if directory else None
#     164 )
#     166 derived_variables: tuple[str, ...] = ()
#     167 if postprocessor is not None:
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/ewatercycle/base/forcing.py:217, in DefaultForcing._run_recipe(cls, recipe, directory)
#     211 @classmethod
#     212 def _run_recipe(
#     213     cls,
#     214     recipe: Recipe,
#     215     directory: Path | None = None,
#     216 ) -> dict[str, str]:
# --> 217     return run_recipe(recipe, directory)
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/ewatercycle/esmvaltool/run.py:109, in run_recipe(recipe, output_dir)
#     100 warnings.filterwarnings(  # Not relevant for end users.
#     101     action="ignore",
#     102     message="Thank you for trying out the new ESMValCore API",
#     103 )
#     104 warnings.filterwarnings(  # Hide Iris warning (upstream issue)
#     105     action="ignore",
#     106     message="Saving to netcdf with legacy-style attribute",
#     107 )
# --> 109 output = _save_and_run_recipe(recipe, output_dir)
#     110 return _parse_recipe_output(output)
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/ewatercycle/esmvaltool/run.py:137, in _save_and_run_recipe(recipe, output_dir)
#     135     esmlvaltool_recipe = ESMValToolRecipe(recipe_path)
#     136     session = _session(output_dir)
# --> 137     output = esmlvaltool_recipe.run(session=session)
#     138 finally:
#     139     recipe_path.unlink()
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/experimental/recipe.py:138, in Recipe.run(self, task, session)
#     136     _dask.check_distributed_config()
#     137     self._engine = self._load(session=session)
# --> 138     self._engine.run()
#     140 shutil.copy2(self.path, session.run_dir)
#     142 output = self.get_output()
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/_recipe/recipe.py:1095, in Recipe.run(self)
#    1092 if self.session['search_esgf'] != 'never':
#    1093     esgf.download(self._download_files, self.session['download_dir'])
# -> 1095 self.tasks.run(max_parallel_tasks=self.session['max_parallel_tasks'])
#    1096 logger.info(
#    1097     "Wrote recipe with version numbers and wildcards "
#    1098     "to:\nfile://%s", filled_recipe)
#    1099 self.write_html_summary()
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/_task.py:738, in TaskSet.run(self, max_parallel_tasks)
#     736     self._run_sequential()
#     737 else:
# --> 738     self._run_parallel(address, max_parallel_tasks)
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/_task.py:782, in TaskSet._run_parallel(self, scheduler_address, max_parallel_tasks)
#     780 ready = {t for t in running if running[t].ready()}
#     781 for task in ready:
# --> 782     _copy_results(task, running[task])
#     783     running.pop(task)
#     785 # Wait if there are still tasks running
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/_task.py:805, in _copy_results(task, future)
#     803 def _copy_results(task, future):
#     804     """Update task with the results from the remote process."""
# --> 805     task.output_files, task.products = future.get()
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/multiprocessing/pool.py:774, in ApplyResult.get(self, timeout)
#     772     return self._value
#     773 else:
# --> 774     raise self._value
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/multiprocessing/pool.py:125, in worker()
#     123 job, i, func, args, kwds = task
#     124 try:
# --> 125     result = (True, func(*args, **kwds))
#     126 except Exception as e:
#     127     if wrap_exception and func is not _helper_reraises_exception:
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/_task.py:816, in _run_task()
#     813     client = Client(scheduler_address)
#     815 with client:
# --> 816     output_files = task.run()
#     818 return output_files, task.products
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/_task.py:264, in run()
#     261 logger.info("Starting task %s in process [%s]", self.name,
#     262             os.getpid())
#     263 start = datetime.datetime.now()
# --> 264 self.output_files = self._run(input_files)
#     265 runtime = datetime.datetime.now() - start
#     266 logger.info("Successfully completed task %s (priority %s) in %s",
#     267             self.name, self.priority, runtime)
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/preprocessor/__init__.py:684, in _run()
#     682 for step in block:
#     683     if step in product.settings:
# --> 684         product.apply(step, self.debug)
#     685 if block == blocks[-1]:
#     686     product.cubes  # pylint: disable=pointless-statement
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/preprocessor/__init__.py:492, in apply()
#     488 if step not in self.settings:
#     489     raise ValueError(
#     490         f"PreprocessorFile {self} has no settings for step {step}"
#     491     )
# --> 492 self.cubes = preprocess(self.cubes, step,
#     493                         input_files=self._input_files,
#     494                         output_file=self.filename,
#     495                         debug=debug,
#     496                         **self.settings[step])
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/preprocessor/__init__.py:502, in cubes()
#     500 """Cubes."""
#     501 if self._cubes is None:
# --> 502     self._cubes = [ds.load() for ds in self.datasets]
#     503 return self._cubes
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/dataset.py:685, in load()
#     682     input_files.extend(supplementary_dataset.files)
#     683 esgf.download(input_files, self.session['download_dir'])
# --> 685 cube = self._load()
#     686 supplementary_cubes = []
#     687 for supplementary_dataset in self.supplementaries:
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/dataset.py:771, in _load()
#     766 result = [
#     767     file.local_file(self.session['download_dir']) if isinstance(
#     768         file, esgf.ESGFFile) else file for file in self.files
#     769 ]
#     770 for step, kwargs in settings.items():
# --> 771     result = preprocess(
#     772         result,
#     773         step,
#     774         input_files=self.files,
#     775         output_file=output_file,
#     776         debug=self.session['save_intermediary_cubes'],
#     777         **kwargs,
#     778     )
#     780 cube = result[0]
#     781 return cube
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/preprocessor/__init__.py:397, in preprocess()
#     395 result = []
#     396 if itype.endswith('s'):
# --> 397     result.append(_run_preproc_function(function, items, settings,
#     398                                         input_files=input_files))
#     399 else:
#     400     for item in items:
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/preprocessor/__init__.py:346, in _run_preproc_function()
#     341 logger.debug(
#     342     "Running preprocessor function '%s' on the data\n%s%s\nwith function "
#     343     "argument(s)\n%s", function.__name__, pformat(items), file_msg,
#     344     kwargs_str)
#     345 try:
# --> 346     return function(items, **kwargs)
#     347 except Exception:
#     348     # To avoid very long error messages, we truncate the arguments and
#     349     # input files here at a given threshold
#     350     n_shown_args = 4
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/preprocessor/_io.py:336, in concatenate()
#     334 merge_cube_attributes(cubes)
#     335 cubes = _sort_cubes_by_time(cubes)
# --> 336 _fix_calendars(cubes)
#     337 cubes = _check_time_overlaps(cubes)
#     338 result = _concatenate_cubes(cubes, check_level=check_level)
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/preprocessor/_io.py:265, in _fix_calendars()
#     261 unique_calendars = np.unique(calendars)
#     263 calendar_ocurrences = np.array(
#     264     [calendars.count(calendar) for calendar in unique_calendars])
# --> 265 calendar_index = int(
#     266     np.argwhere(calendar_ocurrences == calendar_ocurrences.max()))
#     268 for cube in cubes:
#     269     time_coord = cube.coord('time')
#
# TypeError: only 0-dimensional arrays can be converted to Python scalars

# %%
display(ERA5_forcing_object)

# %%
# Quick plot of the precipitation and potential evaporation data
ds_ERA5 = xr.open_mfdataset([ERA5_forcing_object['pr'],ERA5_forcing_object['evspsblpot']])
ds_ERA5["pr"].plot(label = 'precipitation')
ds_ERA5["evspsblpot"].plot(label = 'potential evaporation')
plt.legend()

# %% [markdown]
# ## CMIP historical forcing
# While ERA5 data is hosted by the eWaterCycle team on SURF Research Cloud Machines, data from CMIP is downloaded 'on the fly' when requested.

# %%
display(settings['CMIP_info'])

# %%
# Setting for ESMValTool to make sure the online esgf resources are always used and
# we don't rely on locally cached information.
# CFG['search_esgf'] = 'when_missing'
CFG['search_esgf'] = 'always'
CFG['rootpath'] = {'CMIP6': [Path(settings['path_CMIP6'])], 'default': [Path(settings['path_output'])]}
CFG['download_dir'] = settings['downloads']
print(CFG)

# %%
display(CFG)

# %% [markdown]
# I loop over the datasets and ensemble members to facilitate running this notebook for multiple climate models ('datasets') and ensemble members. If this is required, this needs to be changed in the settings specified in [notebook 0a](step_0a_select_caravan_region_time_and_scenarios.ipynb). This notebook would not have to be changed for this.

# %%
for dataset in settings['CMIP_info']['dataset']:

    for ensemble_member in [settings['CMIP_info']['ensembles'][0]]:

        cmip_dataset = {
            "dataset": dataset,
            "project": settings['CMIP_info']['project'],
            "grid": "gn",
            "exp": "historical",
            "ensemble": ensemble_member,
        }

        display(f"{cmip_dataset = }")

        # Create a subfolder for this specific combination of dataset, experiment and ensemblemember
        path_CMIP6 = Path(settings['path_CMIP6']) / cmip_dataset["dataset"] / cmip_dataset["exp"] / cmip_dataset["ensemble"]
        # path_CMIP6.mkdir(exist_ok=True, parents=True)

        display(path_CMIP6)

        # Generate forcing:
        try:
            load_location = path_CMIP6 / "work" / "diagnostic" / "script" 
            CMIP_forcing_object = ewatercycle.forcing.sources["LumpedMakkinkForcing"].load(directory=load_location)
        except:
            if path_CMIP6.exists():
                shutil.rmtree(path_CMIP6)
            path_CMIP6.mkdir(exist_ok=True, parents=True)
            
            CMIP_forcing_object = ewatercycle.forcing.sources["LumpedMakkinkForcing"].generate(
               dataset=cmip_dataset,
               start_time=settings['calibration_start_date'],
               end_time=settings['validation_end_date'],
               directory=path_CMIP6,
               shape=settings['path_shape'],
            )
            
        display(CMIP_forcing_object)

# %%
# Quick plot of the precipitation and potential evaporation data of the last generated forcing
ds_CMIP = xr.open_mfdataset([CMIP_forcing_object['pr'],CMIP_forcing_object['evspsblpot']])
ds_CMIP["pr"].plot(label = 'precipitation')
ds_CMIP["evspsblpot"].plot(label = 'potential evaporation')
plt.legend()

# %% [markdown]
# ## DestinE CMIP6 historical forcing
#
# The DestinE Climate DT provides a CMIP6 historical simulation using the ICON model at ~40 km resolution (HEALPix H128 grid, referred to as "standard" resolution). The historical run covers 1990 to ~2020, overlapping with both the calibration (1994–2004) and validation (2004–2014) periods used in this workflow.
#
# Data is retrieved via the **polytope API**, a request-based interface to the DestinE data portal. The request specifies the CMIP6 historical activity, the ICON model, and the surface variables needed: 2 m temperature (`t2m`), total precipitation (`tp`), and surface solar radiation downwards (`ssrd`).
#
# Because the data arrives on a HEALPix grid (a pixelised sphere, not a regular lat/lon grid), it is first regridded to a 0.5° regular grid using `earthkit.regrid` before being clipped to the catchment shapefile.
#
# > **Note:** If `generate` is slow, this is expected — the polytope API retrieves multi-year GRIB data and the regridding adds processing time. The result is cached to disk so subsequent calls use `load`.

# %%
# %%capture cap
try:
    # %run desp-authentication.py
except:
    # %run ../scripts/desp-authentication.py

# %%
output_1 = cap.stdout.split('}\n')
access_token = output_1[-1][0:-1]

# %%
# %%time 

# Generate forcing for the calibration + validation period
try:
    DestinE_hist_forcing_object = DestinEHistoricalForcing.load(settings["path_DestinE_historical"])
    print("Loading")
except FileNotFoundError:
# DestinE_hist_forcing_object = DestinEHistoricalForcing.generate(
    print("Generating")
    DestinE_hist_forcing_object = DestinEHistoricalForcing.generate(
        start_time=settings["calibration_start_date"],
        end_time=settings["validation_end_date"],
        # end_time=end_date,
        directory=settings["path_DestinE_historical"],
        shape=settings["path_shape"],
    )

display(DestinE_hist_forcing_object)

# %%
ds_DestinE_hist = xr.open_mfdataset([
    DestinE_hist_forcing_object["pr"],
    DestinE_hist_forcing_object["tas"],
    DestinE_hist_forcing_object["rsds"],
    DestinE_hist_forcing_object["evspsblpot"],
])

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Subplot 1: precipitation + evspsblpot
ds_DestinE_hist["pr"].plot(ax=axes[0], label="precipitation")
ds_DestinE_hist["evspsblpot"].plot(ax=axes[0], label="evspsblpot")
axes[0].set_title("Precipitation & Evap")
axes[0].legend()

# Subplot 2: temperature
ds_DestinE_hist["tas"].plot(ax=axes[1], label="Temperature")
axes[1].set_title("Temperature")
axes[1].legend()

# Subplot 3: radiation
ds_DestinE_hist["rsds"].plot(ax=axes[2], label="Shortwave Radiation")
axes[2].set_title("Shortwave Radiation")
axes[2].legend()

plt.suptitle("DestinE CMIP6 historical (ICON)")
plt.tight_layout()
plt.show()
