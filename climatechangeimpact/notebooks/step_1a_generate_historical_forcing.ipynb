# %% [markdown]
# # HBV hydrological model forced with ERA5 forcing data
# In this notebook we will generate forcing data for the HBV hydrological model from the ERA5 dataset and from a historical CMIP dataset (ie output of a climate model when run for a period of time that represents part of history, not a future prediction).
#
# We use the forcing module of the eWaterCycle platform to easily generate this data.
#
# Later on this forcing will be used to both calibrate and run the HBV hydrological model and produce estimates of river discharge.

# %%
# General python
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

import numpy as np
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import xarray as xr
import json
from esmvalcore.config import CFG
import shutil
import sys
import geopandas as gpd
import rioxarray

# Niceties
from rich import print

# This will work normally for HPC
try:
    from scripts.forcing_destine import DestinEHistoricalForcing
except ImportError:
    # Add the project root to Python path for use on SRC
    project_root = Path().resolve().parent
    sys.path.append(str(project_root))

    from scripts.forcing_destine import DestinEHistoricalForcing

import earthkit.data
import earthkit.regrid
from dask.diagnostics import ProgressBar
from datetime import datetime

# %%
# General eWaterCycle
import ewatercycle
import ewatercycle.forcing

# %%
# Parameters, these get changed when running on HPC
# country = "australia"
# region_id = "camelsaus_102101A"
settings_path = "settings.json"

# %%
# Load settings
# Read from the JSON file
with open(settings_path, "r") as json_file:
    settings = json.load(json_file)

# %%
display(settings)
# Out:
# {'caravan_id': 'camelsaus_102101A',
#  'country': 'australia',
#  'calibration_start_date': '1994-08-01T00:00:00Z',
#  'calibration_end_date': '2004-07-31T00:00:00Z',
#  'validation_start_date': '2004-08-01T00:00:00Z',
#  'validation_end_date': '2014-07-31T00:00:00Z',
#  'future_start_date': '2029-08-01T00:00:00Z',
#  'future_end_date': '2049-08-31T00:00:00Z',
#  'CMIP_info': {'dataset': ['MPI-ESM1-2-LR'],
#   'ensembles': ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1'],
#   'experiments': ['historical', 'ssp126', 'ssp245', 'ssp370', 'ssp585'],
#   'project': 'CMIP6',
#   'grid': 'gn'},
#  'koppen_raster_path': '/data/shared/climate-data/koppen_geiger/1991_2020/koppen_geiger_0p00833333.tif',
#  'base_path': '/home/mmelotto/ewatercycleClimateImpact/HBV',
#  'path_caravan': '/home/mmelotto/ewatercycleClimateImpact/HBV/forcing_data/australia/camelsaus_102101A/caravan',
#  'path_ERA5': '/home/mmelotto/ewatercycleClimateImpact/HBV/forcing_data/australia/camelsaus_102101A/ERA5',
#  'path_DestinE': '/home/mmelotto/ewatercycleClimateImpact/HBV/forcing_data/australia/camelsaus_102101A/DestinE',
#  'path_DestinE_historical': '/home/mmelotto/ewatercycleClimateImpact/HBV/forcing_data/australia/camelsaus_102101A/DestinE_historical',
#  'path_CMIP6': '/home/mmelotto/ewatercycleClimateImpact/HBV/forcing_data/australia/camelsaus_102101A/CMIP6',
#  'path_output': '/home/mmelotto/ewatercycleClimateImpact/HBV/output_data/australia/camelsaus_102101A',
#  'results_path': 'results.json',
#  'path_shape': '/home/mmelotto/ewatercycleClimateImpact/HBV/forcing_data/australia/camelsaus_102101A/caravan/camelsaus_102101A.shp',
#  'downloads': '/home/mmelotto/ewatercycleClimateImpact/HBV/downloads/camelsaus_102101A'}

# %% [markdown]
# ## Generate or load forcing
# When generating forcing using eWaterCycle there are two important choices to make: dataset that the data comes from and type of forcing that the model requires. The dataset in this example is ERA5. The HBV model in eWaterCycle needs potential evaporation data. Both the 'caravan' type forcing as well as the 'LumpedMakkinkForcing' provide potential evaporation. Note that the 'caravan' type forcing only works with the 'caravan' dataset as well, so here we select 'ERA5 for the dataset and LumpedMakkinkForcing for the type.
#
# Note that ERA5 data needs to be stored on the system you are working on. For SURF Research Cloud machines running the eWaterCycle catalog item, this is handled by the eWaterCycle team.
#
# More complex models often require their own type of forcing, for example the wflow model requires 'wflow' type forcing specifically designed for that model, but this is not the case for HBV in eWaterCycle.

# %%
# Generate forcing:
try:
    load_location = Path(settings['path_ERA5']) / "work" / "diagnostic" / "script" 
    ERA5_forcing_object = ewatercycle.forcing.sources["LumpedMakkinkForcing"].load(directory=load_location)
except:    
    ERA5_forcing_object = ewatercycle.forcing.sources["LumpedMakkinkForcing"].generate(
       dataset="ERA5",
       start_time=settings['calibration_start_date'],
       end_time=settings['validation_end_date'],
       directory=settings['path_ERA5'],
       shape=settings['path_shape'],
    )

# %%
display(ERA5_forcing_object)

# %%
# Quick plot of the precipitation and potential evaporation data
ds_ERA5 = xr.open_mfdataset([ERA5_forcing_object['pr'],ERA5_forcing_object['evspsblpot']])
ds_ERA5["pr"].plot(label = 'precipitation')
ds_ERA5["evspsblpot"].plot(label = 'potential evaporation')
plt.legend()

# %% [markdown]
# ## CMIP historical forcing
# While ERA5 data is hosted by the eWaterCycle team on SURF Research Cloud Machines, data from CMIP is downloaded 'on the fly' when requested.

# %%
display(settings['CMIP_info'])
# Out:
# {'dataset': ['MPI-ESM1-2-LR'],
#  'ensembles': ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1'],
#  'experiments': ['historical', 'ssp126', 'ssp245', 'ssp370', 'ssp585'],
#  'project': 'CMIP6',
#  'grid': 'gn'}

# %%
# Setting for ESMValTool to make sure the online esgf resources are always used and
# we don't rely on locally cached information.
# CFG['search_esgf'] = 'when_missing'
CFG['search_esgf'] = 'always'
CFG['rootpath'] = {'CMIP6': [Path(settings['path_CMIP6'])], 'default': [Path(settings['path_output'])]}
CFG['download_dir'] = settings['downloads']
print(CFG)
# Out:
# auxiliary_data_dir: /data/shared/climate-data/aux
# check_level: 3
# compress_netcdf: False
# config_developer_file: /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/config-developer.yml
# config_file: /home/mmelotto/.esmvaltool/config-user.yml
# diagnostics: None
# download_dir: /home/mmelotto/ewatercycleClimateImpact/HBV/downloads/camelsaus_102101A
# drs: {'CMIP5': 'default', 'CORDEX': 'default', 'OBS': 'default', 'CMIP6': 'ESGF'}
# exit_on_warning: False
# extra_facets_dir: ()
# log_level: info
# max_datasets: None
# max_parallel_tasks: None
# max_years: None
# output_dir: /home/mmelotto/home/mmelotto/esmvaltool/output
# output_file_type: png
# profile_diagnostic: False
# remove_preproc_dir: False
# resume_from: []
# rootpath: {'CMIP6':
# [PosixPath('/home/mmelotto/ewatercycleClimateImpact/HBV/forcing_data/australia/camelsaus_102101A/CMIP6')],
# 'default': [PosixPath('/home/mmelotto/ewatercycleClimateImpact/HBV/output_data/australia/camelsaus_102101A')]}
# run_diagnostic: True
# save_intermediary_cubes: False
# search_esgf: always
# skip_nonexistent: False

# %%
display(CFG)
# Out:
# Config({'auxiliary_data_dir': PosixPath('/data/shared/climate-data/aux'),
#         'check_level': <CheckLevels.DEFAULT: 3>,
#         'compress_netcdf': False,
#         'config_developer_file': PosixPath('/opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/esmvalcore/config-developer.yml'),
#         'config_file': PosixPath('/home/mmelotto/.esmvaltool/config-user.yml'),
#         'diagnostics': None,
#         'download_dir': PosixPath('/home/mmelotto/ewatercycleClimateImpact/HBV/downloads/camelsaus_102101A'),
#         'drs': {'CMIP5': 'default',
#                 'CMIP6': 'ESGF',
#                 'CORDEX': 'default',
#                 'OBS': 'default'},
#         'exit_on_warning': False,
#         'extra_facets_dir': (),
#         'log_level': 'info',
#         'max_datasets': None,
#         'max_parallel_tasks': None,
#         'max_years': None,
#         'output_dir': PosixPath('/home/mmelotto/home/mmelotto/esmvaltool/output'),
#         'output_file_type': 'png',
#         'profile_diagnostic': False,
#         'remove_preproc_dir': False,
#         'resume_from': [],
#         'rootpath': {'CMIP6': [PosixPath('/home/mmelotto/ewatercycleClimateImpact/HBV/forcing_data/australia/camelsaus_102101A/CMIP6')],
#                      'default': [PosixPath('/home/mmelotto/ewatercycleClimateImpact/HBV/output_data/australia/camelsaus_102101A')]},
#         'run_diagnostic': True,
#         'save_intermediary_cubes': False,
#         'search_esgf': 'always',
#         'skip_nonexistent': False})

# %% [markdown]
# I loop over the datasets and ensemble members to facilitate running this notebook for multiple climate models ('datasets') and ensemble members. If this is required, this needs to be changed in the settings specified in [notebook 0a](step_0a_select_caravan_region_time_and_scenarios.ipynb). This notebook would not have to be changed for this.

# %%
for dataset in settings['CMIP_info']['dataset']:

    for ensemble_member in [settings['CMIP_info']['ensembles'][0]]:

        cmip_dataset = {
            "dataset": dataset,
            "project": settings['CMIP_info']['project'],
            "grid": "gn",
            "exp": "historical",
            "ensemble": ensemble_member,
        }

        display(f"{cmip_dataset = }")

        # Create a subfolder for this specific combination of dataset, experiment and ensemblemember
        path_CMIP6 = Path(settings['path_CMIP6']) / cmip_dataset["dataset"] / cmip_dataset["exp"] / cmip_dataset["ensemble"]
        # path_CMIP6.mkdir(exist_ok=True, parents=True)

        display(path_CMIP6)

        # Generate forcing:
        try:
            load_location = path_CMIP6 / "work" / "diagnostic" / "script" 
            CMIP_forcing_object = ewatercycle.forcing.sources["LumpedMakkinkForcing"].load(directory=load_location)
        except:
            if path_CMIP6.exists():
                shutil.rmtree(path_CMIP6)
            path_CMIP6.mkdir(exist_ok=True, parents=True)
            
            CMIP_forcing_object = ewatercycle.forcing.sources["LumpedMakkinkForcing"].generate(
               dataset=cmip_dataset,
               start_time=settings['calibration_start_date'],
               end_time=settings['validation_end_date'],
               directory=path_CMIP6,
               shape=settings['path_shape'],
            )
            
        display(CMIP_forcing_object)
# Out:
# "cmip_dataset = {'dataset': 'MPI-ESM1-2-LR', 'project': 'CMIP6', 'grid': 'gn', 'exp': 'historical', 'ensemble': 'r1i1p1f1'}"
# PosixPath('/home/mmelotto/ewatercycleClimateImpact/HBV/forcing_data/australia/camelsaus_102101A/CMIP6/MPI-ESM1-2-LR/historical/r1i1p1f1')
# LumpedMakkinkForcing(start_time='1994-08-01T00:00:00Z', end_time='2014-07-31T00:00:00Z', directory=PosixPath('/home/mmelotto/ewatercycleClimateImpact/HBV/forcing_data/australia/camelsaus_102101A/CMIP6/MPI-ESM1-2-LR/historical/r1i1p1f1/work/diagnostic/script'), shape=PosixPath('/home/mmelotto/ewatercycleClimateImpact/HBV/forcing_data/australia/camelsaus_102101A/CMIP6/MPI-ESM1-2-LR/historical/r1i1p1f1/work/diagnostic/script/camelsaus_102101A.shp'), filenames={'pr': 'CMIP6_MPI-ESM1-2-LR_day_historical_r1i1p1f1_pr_gn_1994-2014.nc', 'tas': 'CMIP6_MPI-ESM1-2-LR_day_historical_r1i1p1f1_tas_gn_1994-2014.nc', 'rsds': 'CMIP6_MPI-ESM1-2-LR_day_historical_r1i1p1f1_rsds_gn_1994-2014.nc', 'evspsblpot': 'Derived_Makkink_evspsblpot.nc'})

# %%
# Quick plot of the precipitation and potential evaporation data of the last generated forcing
ds_CMIP = xr.open_mfdataset([CMIP_forcing_object['pr'],CMIP_forcing_object['evspsblpot']])
ds_CMIP["pr"].plot(label = 'precipitation')
ds_CMIP["evspsblpot"].plot(label = 'potential evaporation')
plt.legend()
# Out:
# /tmp/ipykernel_54398/2825575744.py:2: FutureWarning: In a future version of xarray the default value for compat will change from compat='no_conflicts' to compat='override'. This is likely to lead to different results when combining overlapping variables with the same name. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set compat explicitly.
# /tmp/ipykernel_54398/2825575744.py:2: FutureWarning: In a future version of xarray the default value for compat will change from compat='no_conflicts' to compat='override'. This is likely to lead to different results when combining overlapping variables with the same name. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set compat explicitly.

# %% [markdown]
# ## DestinE CMIP6 historical forcing
#
# The DestinE Climate DT provides a CMIP6 historical simulation using the ICON model at ~40 km resolution (HEALPix H128 grid, referred to as "standard" resolution). The historical run covers 1990 to ~2020, overlapping with both the calibration (1994–2004) and validation (2004–2014) periods used in this workflow.
#
# Data is retrieved via the **polytope API**, a request-based interface to the DestinE data portal. The request specifies the CMIP6 historical activity, the ICON model, and the surface variables needed: 2 m temperature (`t2m`), total precipitation (`tp`), and surface solar radiation downwards (`ssrd`).
#
# Because the data arrives on a HEALPix grid (a pixelised sphere, not a regular lat/lon grid), it is first regridded to a 0.5° regular grid using `earthkit.regrid` before being clipped to the catchment shapefile.
#
# > **Note:** If `generate` is slow, this is expected — the polytope API retrieves multi-year GRIB data and the regridding adds processing time. The result is cached to disk so subsequent calls use `load`.

# %%
# %%capture cap
try:
    # %run scripts/desp-authentication.py
except:
    # %run ../scripts/desp-authentication.py

# %%
output_1 = cap.stdout.split('}\n')
access_token = output_1[-1][0:-1]

# %%
# %%time 

# Generate forcing for the calibration + validation period
try:
    DestinE_hist_forcing_object = DestinEHistoricalForcing.load(settings["path_DestinE_historical"])
    print("Loading")
except FileNotFoundError:
# DestinE_hist_forcing_object = DestinEHistoricalForcing.generate(
    print("Generating")
    DestinE_hist_forcing_object = DestinEHistoricalForcing.generate(
        start_time=settings["calibration_start_date"],
        end_time=settings["validation_end_date"],
        directory=settings["path_DestinE_historical"],
        shape=settings["path_shape"],
    )

display(DestinE_hist_forcing_object)
# Out:
# Generating
# 2026-04-14 15:53:04 - INFO - Key read from /home/mmelotto/.polytopeapirc
# 2026-04-14 15:53:04 - INFO - Sending request...
# {'request': 'activity: CMIP6\n'
#             'class: ng\n'
#             'date: 19940801/to/19981231\n'
#             'experiment: hist\n'
#             "expver: '0001'\n"
#             'feature:\n'
#             '  shape:\n'
#             '  - - -12.837083332999953\n'
#             '    - 143.18319444500003\n'
#             '  - - -12.833472221999955\n'
#             '    - 143.1851388890001\n'
#             '  - - -12.833194443999957\n'
#             '    - 143.1829166670001\n'
#             '  - - -12.828194443999962\n'
#             '    - 143.17847222300009\n'
#             '  - - -12.829861110999957\n'
#             '    - 143.1751388890001\n'
#             '  - - -12.828749999999957\n'
#             '    - 143.1673611120001\n'
#             '  - - -12.825972221999962\n'
#             '    - 143.1656944450001\n'
#             '  - - -12.822083332999966\n'
#             '    - 143.1679166670001\n'
#             '  - - -12.81486111099997\n'
#             '    - 143.16652777800005\n'
#             '  - - -12.807361110999977\n'
#             '    - 143.18152777800003\n'
#             '  - - -12.80291666599993\n'
#             '    - 143.18347222300008\n'
#             '  - - -12.802361110999982\n'
#             '    - 143.1851388890001\n'
#             '  - - -12.791527776999942\n'
#             '    - 143.18708333400002\n'
#             '  - - -12.79069444399994\n'
#             '    - 143.18847222300008\n'
#             '  - - -12.788472221999939\n'
#             '    - 143.18847222300008\n'
#             '  - - -12.787361110999939\n'
#             '    - 143.18625000100008\n'
#             '  - - -12.78374999999994\n'
#             '    - 143.18625000100008\n'
#             '  - - -12.782916665999949\n'
#             '    - 143.19069444500008\n'
#             '  - - -12.775416665999956\n'
#             '    - 143.19263888900002\n'
#             '  - - -12.772916665999958\n'
#             '    - 143.19541666700002\n'
#             '  - - -12.767361110999957\n'
#             '    - 143.19736111200007\n'
#             '  - - -12.765694443999962\n'
#             '    - 143.19986111200012\n'
#             '  - - -12.769583332999957\n'
#             '    - 143.202638889\n'
#             '  - - -12.76819444399996\n'
#             '    - 143.20375000100012\n'
#             '  - - -12.768472221999957\n'
#             '    - 143.206527778\n'
#             '  - - -12.765694443999962\n'
#             '    - 143.20569444500006\n'
#             '  - - -12.763749999999959\n'
#             '    - 143.20736111200006\n'
#             '  - - -12.763749999999959\n'
#             '    - 143.21152777800012\n'
#             '  - - -12.768472221999957\n'
#             '    - 143.21291666700006\n'
#             '  - - -12.768472221999957\n'
#             '    - 143.2165277780001\n'
#             '  - - -12.775416665999956\n'
#             '    - 143.2187500010001\n'
#             '  - - -12.779861110999946\n'
#             '    - 143.21625000100005\n'
#             '  - - -12.782083332999946\n'
#             '    - 143.2187500010001\n'
#             '    - 143.1673611120001\n'
#             '  - - -12.839027776999956\n'
#             '    - 143.17486111200003\n'
#             '  - - -12.83847222199995\n'
#             '    - 143.17819444500003\n'
#             '  - - -12.835416665999958\n'
#             '    - 143.1801388890001\n'
#             '  - - -12.837083332999953\n'
#             '    - 143.18319444500003\n'
#             '  type: polygon\n'
#             "generation: '1'\n"
#             'levtype: sfc\n'
#             'model: IFS-FESOM\n'
#             'param: 167/260048/169\n'
#             "realization: '1'\n"
#             'resolution: high\n'
#             'stream: clte\n'
#             'time: '
#             '0000/0100/0200/0300/0400/0500/0600/0700/0800/0900/1000/1100/1200/1300/1400/1500/1600/1700/1800/1900/2000/2100/2200/2300\n'
#             'type: fc\n',
#  'verb': 'retrieve'}
# 2026-04-14 15:53:04 - INFO - Polytope user key found in session cache for user mmelotto
# Data is split up in parts
# Running 1 of 5
# start = '19940801'
# end = '19981231'
# 2026-04-14 15:53:29 - WARNING - Recovering from connection error.
# HTTPSConnectionPool(host='polytope.lumi.apps.dte.destination-earth.eu', port=443): Max retries exceeded with url: /api/v1/requests/destination-earth (Caused by NameResolutionError("HTTPSConnection(host='polytope.lumi.apps.dte.destination-earth.eu', port=443): Failed to resolve 'polytope.lumi.apps.dte.destination-earth.eu' ([Errno -3] Temporary failure in name resolution)"))
# 2026-04-14 15:53:29 - INFO - Attempt 1 of 10
# 2026-04-14 15:53:29 - INFO - Next retry in 120 seconds
# 2026-04-14 15:55:30 - INFO - Request accepted. Please poll ./ab4a3775-6995-4848-99ae-96a5d67e7c73 for status
# 2026-04-14 15:55:30 - INFO - Polytope user key found in session cache for user mmelotto
# 2026-04-14 15:55:30 - INFO - Checking request status (ab4a3775-6995-4848-99ae-96a5d67e7c73)...
# 2026-04-14 15:55:38 - INFO - The current status of the request is 'processing'
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File <timed exec>:3
#
# File ~/seamless_spider/climatechangeimpact/scripts/forcing_destine.py:389, in DestinEHistoricalForcing.load(cls, directory)
#     387 directory = str(directory)
# --> 389 with open(Path(directory) / "ewatercycle_forcing.yaml", "r") as f:
#     390     config = yaml.safe_load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/mmelotto/ewatercycleClimateImpact/HBV/forcing_data/australia/camelsaus_102101A/DestinE_historical/ewatercycle_forcing.yaml'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', '\n# Generate forcing for the calibration + validation period\ntry:\n    DestinE_hist_forcing_object = DestinEHistoricalForcing.load(settings["path_DestinE_historical"])\n    print("Loading")\nexcept FileNotFoundError:\n# DestinE_hist_forcing_object = DestinEHistoricalForcing.generate(\n    print("Generating")\n    DestinE_hist_forcing_object = DestinEHistoricalForcing.generate(\n        start_time=settings["calibration_start_date"],\n        end_time=settings["validation_end_date"],\n        directory=settings["path_DestinE_historical"],\n        shape=settings["path_shape"],\n    )\n\ndisplay(DestinE_hist_forcing_object)\n')
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/IPython/core/interactiveshell.py:2543, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2541 with self.builtin_trap:
#    2542     args = (magic_arg_s, cell)
# -> 2543     result = fn(*args, **kwargs)
#    2545 # The code below prevents the output from being displayed
#    2546 # when using magics with decorator @output_can_be_silenced
#    2547 # when the last Python token in the expression is a ';'.
#    2548 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/IPython/core/magics/execution.py:1370, in ExecutionMagics.time(self, line, cell, local_ns)
#    1368 st = clock2()
#    1369 try:
# -> 1370     exec(code, glob, local_ns)
#    1371     out = None
#    1372     # multi-line %%time case
#
# File <timed exec>:8
#
# File ~/seamless_spider/climatechangeimpact/scripts/forcing_destine.py:462, in DestinEHistoricalForcing.generate(cls, start_time, end_time, directory, variables, shape, polytope_address, **kwargs)
#     459 LIVE_REQUEST = os.getenv("LIVE_REQUEST", "true").lower() == "true"
#     461 if LIVE_REQUEST:
# --> 462     data = earthkit.data.from_source("polytope", "destination-earth", request, address=polytope_address, stream=False)
#     464 ds = data.to_xarray()
#     465 ds = ds.rename({
#     466     "2t": "tas",
#     467     "ssrd": "rsds",
#     468     "tprate": "pr"
#     469 })
#
# File ~/.local/lib/python3.12/site-packages/earthkit/data/sources/__init__.py:145, in from_source(name, lazily, *args, **kwargs)
#     143 while src is not prev:
#     144     prev = src
# --> 145     src = src.mutate()
#     146 return src
#
# File ~/.local/lib/python3.12/site-packages/earthkit/data/sources/polytope.py:106, in Polytope.mutate(self)
#     104     return self._mutate_stream()
#     105 else:
# --> 106     return self._retrieve()
#
# File ~/.local/lib/python3.12/site-packages/earthkit/data/sources/polytope.py:163, in Polytope._retrieve(self)
#     161 # Download each request in parallel when the config allows it
#     162 retriever = FileRequestRetriever(self, retriever=_retrieve_one)
# --> 163 path = retriever.retrieve(self.request, self.dataset)
#     165 # TODO: for simplicity we assume all retrieved files have the same content-type. Revisit if needed.
#     166 content_type = None
#
# File ~/.local/lib/python3.12/site-packages/earthkit/data/utils/request.py:135, in FileRequestRetriever.retrieve(self, requests, *extra_args)
#     132 nthreads = min(self.owner.config("number-of-download-threads"), len(requests))
#     134 if nthreads < 2:
# --> 135     path = [self.retriever(r, *extra_args) for r in requests]
#     136 else:
#     137     from earthkit.data.utils.progbar import tqdm
#
# File ~/.local/lib/python3.12/site-packages/earthkit/data/sources/polytope.py:156, in Polytope._retrieve.<locals>._retrieve_one(request, dataset)
#     152     return download_to_target(url, target)
#     154 # The cache file path/data is constructed by using the request only. We cannot simply base
#     155 # it on the URL since the URL may change every time we ask for the pointers.
# --> 156 return self.cache_file(
#     157     retrieve,
#     158     (dataset, request),
#     159 )
#
# File ~/.local/lib/python3.12/site-packages/earthkit/data/sources/__init__.py:65, in Source.cache_file(self, create, args, **kwargs)
#      62 if owner is None:
#      63     owner = re.sub(r"(?!^)([A-Z]+)", r"-\1", self.__class__.__name__).lower()
# ---> 65 return cache_file(owner, create, args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/earthkit/data/core/caching.py:1099, in cache_file(owner, create, args, hash_extra, extension, force, replace)
#    1097 with FileLock(lock):
#    1098     if not os.path.exists(path):  # Check again, another thread/process may have created the file
# -> 1099         owner_data = create(path + ".tmp", args)
#    1100         os.rename(path + ".tmp", path)
#    1101 try:
#
# File ~/.local/lib/python3.12/site-packages/earthkit/data/sources/polytope.py:140, in Polytope._retrieve.<locals>._retrieve_one.<locals>.retrieve(target, args)
#     135 """
#     136 Caching callback method to retrieve data into target file. Only called if
#     137 the data is not already cached.
#     138 """
#     139 # get the pointer and the url to download
# --> 140 pointers = self.client.retrieve(
#     141     args[0],
#     142     args[1],
#     143     pointer=True,
#     144     asynchronous=False,
#     145 )
#     147 url = pointers[0]["location"]
#     149 # download the file and return the associated HTTP header info.
#     150 # This might contain useful info such as content-type. It will be
#     151 # stored in the cache database.
#
# File ~/.local/lib/python3.12/site-packages/polytope/api/helpers.py:197, in wraps.<locals>.wrapper.<locals>.decorated(self, *args, **kwargs)
#     196 def decorated(self, *args, **kwargs):
# --> 197     return fun(self, *args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/polytope/api/helpers.py:229, in authenticated.<locals>.decorated(self, *args, **kwargs)
#     227     raise e
#     228 # try:
# --> 229 return method(self, *args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/polytope/api/helpers.py:197, in wraps.<locals>.wrapper.<locals>.decorated(self, *args, **kwargs)
#     196 def decorated(self, *args, **kwargs):
# --> 197     return fun(self, *args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/polytope/api/Client.py:202, in Client.retrieve(self, *args, **kwargs)
#     199 @authenticated
#     200 @wraps(RequestManager.retrieve)
#     201 def retrieve(self, *args, **kwargs):
# --> 202     return self.request_manager.retrieve(*args, **kwargs)
#
# File ~/.local/lib/python3.12/site-packages/polytope/api/RequestManager.py:438, in RequestManager.retrieve(self, name, request, output_file, inline_request, asynchronous, max_attempts, attempt_period, append, pointer)
#     436         request_results[i] = Result(request_url, output_file, append, self)
#     437     else:
# --> 438         request_results[i] = self.download(
#     439             request_id, output_file, asynchronous, max_attempts, attempt_period, append, pointer
#     440         )
#     442     append = True
#     444 for warning in warnings:
#
# File ~/.local/lib/python3.12/site-packages/polytope/api/RequestManager.py:683, in RequestManager.download(self, request_id, output_file, asynchronous, max_attempts, attempt_period, append, pointer)
#     679     e = helpers.RetriesExceededError(
#     680         attempts=describe_max_attempts, situation=situation, url=url, method=method, request_content=headers
#     681     )
#     682     raise e
# --> 683 response, response_messages = helpers.try_request(
#     684     method,
#     685     situation=situation,
#     686     expected=expected_responses,
#     687     logger=self._logger,
#     688     stream=True,
#     689     url=url,
#     690     headers=headers,
#     691     skip_tls=self.config.get()["skip_tls"],
#     692     session=s,
#     693 )
#     694 if response.status_code == requests.codes.ok:
#     695     last_status = "processed"
#
# File ~/.local/lib/python3.12/site-packages/polytope/api/helpers.py:604, in try_request(method, situation, expected, logger, stream, skip_tls, session, **kwargs)
#     601     logger.warning("Maximum HTTP request retries reached")
#     602     raise e
# --> 604 response_title, response_messages = process_response(
#     605     response, situation, url, method, stream, request_content, expected
#     606 )
#     608 logger.debug("Polytope client received HTTP " + response_title)
#     610 return response, response_messages
#
# File ~/.local/lib/python3.12/site-packages/polytope/api/helpers.py:498, in process_response(response, situation, url, method, stream, request_content, expected)
#     496 else:
#     497     try:
# --> 498         response_messages = response.json()
#     499         # the following lines force the response to always be a dictionary, for code simplicity
#     500         if not isinstance(response_messages, dict):
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/requests/models.py:955, in Response.json(self, **kwargs)
#     947 def json(self, **kwargs):
#     948     r"""Returns the json-encoded content of a response, if any.
#     949
#     950     :param \*\*kwargs: Optional arguments that ``json.loads`` takes.
#     951     :raises requests.exceptions.JSONDecodeError: If the response body does not
#     952         contain valid json.
#     953     """
# --> 955     if not self.encoding and self.content and len(self.content) > 3:
#     956         # No encoding set. JSON RFC 4627 section 3 states we should expect
#     957         # UTF-8, -16 or -32. Detect which one to use; If the detection or
#     958         # decoding fails, fall back to `self.text` (using charset_normalizer to make
#     959         # a best guess).
#     960         encoding = guess_json_utf(self.content)
#     961         if encoding is not None:
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/requests/models.py:902, in Response.content(self)
#     900         self._content = None
#     901     else:
# --> 902         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     904 self._content_consumed = True
#     905 # don't need to release the connection; that's been handled by urllib3
#     906 # since we exhausted the data.
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/site-packages/requests/models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File ~/.local/lib/python3.12/site-packages/urllib3/response.py:1257, in HTTPResponse.stream(self, amt, decode_content)
#    1251 else:
#    1252     while (
#    1253         not is_fp_closed(self._fp)
#    1254         or len(self._decoded_buffer) > 0
#    1255         or (self._decoder and self._decoder.has_unconsumed_tail)
#    1256     ):
# -> 1257         data = self.read(amt=amt, decode_content=decode_content)
#    1259         if data:
#    1260             yield data
#
# File ~/.local/lib/python3.12/site-packages/urllib3/response.py:1112, in HTTPResponse.read(self, amt, decode_content, cache_content)
#    1109     if len(self._decoded_buffer) >= amt:
#    1110         return self._decoded_buffer.get(amt)
# -> 1112 data = self._raw_read(amt)
#    1114 flush_decoder = amt is None or (amt != 0 and not data)
#    1116 if (
#    1117     not data
#    1118     and len(self._decoded_buffer) == 0
#    1119     and not (self._decoder and self._decoder.has_unconsumed_tail)
#    1120 ):
#
# File ~/.local/lib/python3.12/site-packages/urllib3/response.py:1028, in HTTPResponse._raw_read(self, amt, read1)
#    1025 fp_closed = getattr(self._fp, "closed", False)
#    1027 with self._error_catcher():
# -> 1028     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#    1029     if amt is not None and amt != 0 and not data:
#    1030         # Platform-specific: Buggy versions of Python.
#    1031         # Close the connection when no data is returned
#    (...)
#    1036         # not properly close the connection in all cases. There is
#    1037         # no harm in redundantly calling close.
#    1038         self._fp.close()
#
# File ~/.local/lib/python3.12/site-packages/urllib3/response.py:1011, in HTTPResponse._fp_read(self, amt, read1)
#    1008     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#    1009 else:
#    1010     # StringIO doesn't like amt=None
# -> 1011     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/http/client.py:479, in HTTPResponse.read(self, amt)
#     476 if self.length is not None and amt > self.length:
#     477     # clip the read to the "end of response"
#     478     amt = self.length
# --> 479 s = self.fp.read(amt)
#     480 if not s and amt:
#     481     # Ideally, we would raise IncompleteRead if the content-length
#     482     # wasn't satisfied, but it might break compatibility.
#     483     self._close_conn()
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/socket.py:720, in SocketIO.readinto(self, b)
#     718 while True:
#     719     try:
# --> 720         return self._sock.recv_into(b)
#     721     except timeout:
#     722         self._timeout_occurred = True
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1247     if flags != 0:
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#    1253     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/conda/envs/ewatercycle2/lib/python3.12/ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1101 try:
#    1102     if buffer is not None:
# -> 1103         return self._sslobj.read(len, buffer)
#    1104     else:
#    1105         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
ds_DestinE_hist = xr.open_mfdataset([
    DestinE_hist_forcing_object["pr"],
    DestinE_hist_forcing_object["tas"],
    DestinE_hist_forcing_object["rsds"],
    DestinE_hist_forcing_object["evspsblpot"],
])

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Subplot 1: precipitation + evspsblpot
ds_DestinE_hist["pr"].plot(ax=axes[0], label="precipitation")
ds_DestinE_hist["evspsblpot"].plot(ax=axes[0], label="evspsblpot")
axes[0].set_title("Precipitation & Evap")
axes[0].legend()

# Subplot 2: temperature
ds_DestinE_hist["tas"].plot(ax=axes[1], label="Temperature")
axes[1].set_title("Temperature")
axes[1].legend()

# Subplot 3: radiation
ds_DestinE_hist["rsds"].plot(ax=axes[2], label="Shortwave Radiation")
axes[2].set_title("Shortwave Radiation")
axes[2].legend()

plt.suptitle("DestinE CMIP6 historical (IFS-FESOM)")
plt.tight_layout()
plt.show()
