# %% [markdown]
# # HBV hydrological model forced with ERA5 forcing data
# In this notebook we will generate forcing data for the HBV hydrological model from the ERA5 dataset and from a historical CMIP dataset (ie output of a climate model when run for a period of time that represents part of history, not a future prediction).
#
# We use the forcing module of the eWaterCycle platform to easily generate this data.
#
# Later on this forcing will be used to both calibrate and run the HBV hydrological model and produce estimates of river discharge.

# %%
# General python
import warnings
warnings.filterwarnings("ignore", category=UserWarning)

import numpy as np
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import xarray as xr
import json
from esmvalcore.config import CFG
import shutil
import sys
import geopandas as gpd
import rioxarray

# Niceties
from rich import print

# This will work normally for HPC
try:
    from scripts.forcing_destine import DestinEHistoricalForcing
except ImportError:
    # Add the project root to Python path for use on SRC
    project_root = Path().resolve().parent
    sys.path.append(str(project_root))

    from scripts.forcing_destine import DestinEHistoricalForcing

import earthkit.data
import earthkit.regrid
from dask.diagnostics import ProgressBar
from datetime import datetime

# %%
# General eWaterCycle
import ewatercycle
import ewatercycle.forcing

# %%
# Parameters, these get changed when running on HPC
# country = "australia"
# region_id = "camelsaus_102101A"
settings_path = "settings.json"

# %%
# Parameters
settings_path = "regions/mexico/hysets_10034/settings.json"

# %%
# Load settings
# Read from the JSON file
with open(settings_path, "r") as json_file:
    settings = json.load(json_file)

# %%
display(settings)
# Out:
# {'caravan_id': 'hysets_10034',
#  'country': 'mexico',
#  'calibration_start_date': '1994-08-01T00:00:00Z',
#  'calibration_end_date': '2004-07-31T00:00:00Z',
#  'validation_start_date': '2004-08-01T00:00:00Z',
#  'validation_end_date': '2014-07-31T00:00:00Z',
#  'future_start_date': '2029-08-01T00:00:00Z',
#  'future_end_date': '2049-08-31T00:00:00Z',
#  'CMIP_info': {'dataset': ['MPI-ESM1-2-LR'],
#   'ensembles': ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1'],
#   'experiments': ['historical', 'ssp126', 'ssp245', 'ssp370', 'ssp585'],
#   'project': 'CMIP6',
#   'grid': 'gn'},
#  'koppen_raster_path': '/home/ewater-mmelotto/koppen_geiger/1991_2020/koppen_geiger_0p00833333.tif',
#  'base_path': '/project/ewater/Data/ewatercycleClimateImpact/HBV',
#  'path_caravan': '/project/ewater/Data/ewatercycleClimateImpact/HBV/forcing_data/mexico/hysets_10034/caravan',
#  'path_ERA5': '/project/ewater/Data/ewatercycleClimateImpact/HBV/forcing_data/mexico/hysets_10034/ERA5',
#  'path_DestinE': '/project/ewater/Data/ewatercycleClimateImpact/HBV/forcing_data/mexico/hysets_10034/DestinE',
#  'path_DestinE_historical': '/project/ewater/Data/ewatercycleClimateImpact/HBV/forcing_data/mexico/hysets_10034/DestinE_historical',
#  'path_CMIP6': '/project/ewater/Data/ewatercycleClimateImpact/HBV/forcing_data/mexico/hysets_10034/CMIP6',
#  'path_output': '/project/ewater/Data/ewatercycleClimateImpact/HBV/output_data/mexico/hysets_10034',
#  'results_path': 'regions/mexico/hysets_10034/results.json',
#  'figure_output': 'regions/mexico/hysets_10034/figures',
#  'path_shape': '/project/ewater/Data/ewatercycleClimateImpact/HBV/forcing_data/mexico/hysets_10034/caravan/hysets_10034.shp',
#  'downloads': '/project/ewater/Data/ewatercycleClimateImpact/HBV/downloads/hysets_10034'}

# %% [markdown]
# ## Generate or load forcing
# When generating forcing using eWaterCycle there are two important choices to make: dataset that the data comes from and type of forcing that the model requires. The dataset in this example is ERA5. The HBV model in eWaterCycle needs potential evaporation data. Both the 'caravan' type forcing as well as the 'LumpedMakkinkForcing' provide potential evaporation. Note that the 'caravan' type forcing only works with the 'caravan' dataset as well, so here we select 'ERA5 for the dataset and LumpedMakkinkForcing for the type.
#
# Note that ERA5 data needs to be stored on the system you are working on. For SURF Research Cloud machines running the eWaterCycle catalog item, this is handled by the eWaterCycle team.
#
# More complex models often require their own type of forcing, for example the wflow model requires 'wflow' type forcing specifically designed for that model, but this is not the case for HBV in eWaterCycle.

# %%
# Generate forcing:
try:
    load_location = Path(settings['path_ERA5']) / "work" / "diagnostic" / "script" 
    ERA5_forcing_object = ewatercycle.forcing.sources["LumpedMakkinkForcing"].load(directory=load_location)
except:    
    ERA5_forcing_object = ewatercycle.forcing.sources["LumpedMakkinkForcing"].generate(
       dataset="ERA5",
       start_time=settings['calibration_start_date'],
       end_time=settings['validation_end_date'],
       directory=settings['path_ERA5'],
       shape=settings['path_shape'],
    )

# %%
display(ERA5_forcing_object)
# Out:
# LumpedMakkinkForcing(start_time='1994-08-01T00:00:00Z', end_time='2014-07-31T00:00:00Z', directory=PosixPath('/project/ewater/Data/ewatercycleClimateImpact/HBV/forcing_data/mexico/hysets_10034/ERA5/work/diagnostic/script'), shape=PosixPath('/project/ewater/Data/ewatercycleClimateImpact/HBV/forcing_data/mexico/hysets_10034/ERA5/work/diagnostic/script/hysets_10034.shp'), filenames={'pr': 'OBS6_ERA5_reanaly_1_day_pr_1994-2014.nc', 'tas': 'OBS6_ERA5_reanaly_1_day_tas_1994-2014.nc', 'rsds': 'OBS6_ERA5_reanaly_1_day_rsds_1994-2014.nc', 'evspsblpot': 'Derived_Makkink_evspsblpot.nc'})

# %%
# Quick plot of the precipitation and potential evaporation data
ds_ERA5 = xr.open_mfdataset([ERA5_forcing_object['pr'],ERA5_forcing_object['evspsblpot']])
ds_ERA5["pr"].plot(label = 'precipitation')
ds_ERA5["evspsblpot"].plot(label = 'potential evaporation')
plt.legend()
# Out:
# /tmp/ipykernel_309645/1279259822.py:2: FutureWarning: In a future version of xarray the default value for compat will change from compat='no_conflicts' to compat='override'. This is likely to lead to different results when combining overlapping variables with the same name. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set compat explicitly.
# /tmp/ipykernel_309645/1279259822.py:2: FutureWarning: In a future version of xarray the default value for compat will change from compat='no_conflicts' to compat='override'. This is likely to lead to different results when combining overlapping variables with the same name. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set compat explicitly.

# %% [markdown]
# ## CMIP historical forcing
# While ERA5 data is hosted by the eWaterCycle team on SURF Research Cloud Machines, data from CMIP is downloaded 'on the fly' when requested.

# %%
display(settings['CMIP_info'])
# Out:
# {'dataset': ['MPI-ESM1-2-LR'],
#  'ensembles': ['r1i1p1f1', 'r2i1p1f1', 'r3i1p1f1'],
#  'experiments': ['historical', 'ssp126', 'ssp245', 'ssp370', 'ssp585'],
#  'project': 'CMIP6',
#  'grid': 'gn'}

# %%
# Setting for ESMValTool to make sure the online esgf resources are always used and
# we don't rely on locally cached information.
# CFG['search_esgf'] = 'when_missing'
CFG['search_esgf'] = 'always'
CFG['rootpath'] = {'CMIP6': [Path(settings['path_CMIP6'])], 'default': [Path(settings['path_output'])]}
CFG['download_dir'] = settings['downloads']
print(CFG)
# Out:
# auxiliary_data_dir: /home/ewater-mmelotto/auxiliary_data
# check_level: 3
# compress_netcdf: False
# config_developer_file:
# /home/ewater-mmelotto/miniforge3/envs/ewatercycle_spider/lib/python3.12/site-packages/esmvalcore/config-developer.y
# ml
# config_file:
# /home/ewater-mmelotto/miniforge3/envs/ewatercycle_spider/lib/python3.12/site-packages/esmvalcore/config-user.yml
# diagnostics: None
# download_dir: /project/ewater/Data/ewatercycleClimateImpact/HBV/downloads/hysets_10034
# drs: {'CMIP3': 'ESGF', 'CMIP5': 'ESGF', 'CMIP6': 'ESGF', 'CORDEX': 'ESGF', 'obs4MIPs': 'ESGF'}
# exit_on_warning: False
# extra_facets_dir: ()
# log_level: info
# max_datasets: None
# max_parallel_tasks: None
# max_years: None
# output_dir: /home/ewater-mmelotto/esmvaltool_output
# output_file_type: png
# profile_diagnostic: False
# remove_preproc_dir: True
# resume_from: []
# rootpath: {'CMIP6':
# [PosixPath('/project/ewater/Data/ewatercycleClimateImpact/HBV/forcing_data/mexico/hysets_10034/CMIP6')], 'default':
# [PosixPath('/project/ewater/Data/ewatercycleClimateImpact/HBV/output_data/mexico/hysets_10034')]}
# run_diagnostic: True
# save_intermediary_cubes: False
# search_esgf: always
# skip_nonexistent: False

# %%
display(CFG)
# Out:
# Config({'auxiliary_data_dir': PosixPath('/home/ewater-mmelotto/auxiliary_data'),
#         'check_level': <CheckLevels.DEFAULT: 3>,
#         'compress_netcdf': False,
#         'config_developer_file': PosixPath('/home/ewater-mmelotto/miniforge3/envs/ewatercycle_spider/lib/python3.12/site-packages/esmvalcore/config-developer.yml'),
#         'config_file': PosixPath('/home/ewater-mmelotto/miniforge3/envs/ewatercycle_spider/lib/python3.12/site-packages/esmvalcore/config-user.yml'),
#         'diagnostics': None,
#         'download_dir': PosixPath('/project/ewater/Data/ewatercycleClimateImpact/HBV/downloads/hysets_10034'),
#         'drs': {'CMIP3': 'ESGF',
#                 'CMIP5': 'ESGF',
#                 'CMIP6': 'ESGF',
#                 'CORDEX': 'ESGF',
#                 'obs4MIPs': 'ESGF'},
#         'exit_on_warning': False,
#         'extra_facets_dir': (),
#         'log_level': 'info',
#         'max_datasets': None,
#         'max_parallel_tasks': None,
#         'max_years': None,
#         'output_dir': PosixPath('/home/ewater-mmelotto/esmvaltool_output'),
#         'output_file_type': 'png',
#         'profile_diagnostic': False,
#         'remove_preproc_dir': True,
#         'resume_from': [],
#         'rootpath': {'CMIP6': [PosixPath('/project/ewater/Data/ewatercycleClimateImpact/HBV/forcing_data/mexico/hysets_10034/CMIP6')],
#                      'default': [PosixPath('/project/ewater/Data/ewatercycleClimateImpact/HBV/output_data/mexico/hysets_10034')]},
#         'run_diagnostic': True,
#         'save_intermediary_cubes': False,
#         'search_esgf': 'always',
#         'skip_nonexistent': False})

# %% [markdown]
# I loop over the datasets and ensemble members to facilitate running this notebook for multiple climate models ('datasets') and ensemble members. If this is required, this needs to be changed in the settings specified in [notebook 0a](step_0a_select_caravan_region_time_and_scenarios.ipynb). This notebook would not have to be changed for this.

# %%
for dataset in settings['CMIP_info']['dataset']:

    for ensemble_member in [settings['CMIP_info']['ensembles'][0]]:

        cmip_dataset = {
            "dataset": dataset,
            "project": settings['CMIP_info']['project'],
            "grid": "gn",
            "exp": "historical",
            "ensemble": ensemble_member,
        }

        display(f"{cmip_dataset = }")

        # Create a subfolder for this specific combination of dataset, experiment and ensemblemember
        path_CMIP6 = Path(settings['path_CMIP6']) / cmip_dataset["dataset"] / cmip_dataset["exp"] / cmip_dataset["ensemble"]
        # path_CMIP6.mkdir(exist_ok=True, parents=True)

        display(path_CMIP6)

        # Generate forcing:
        try:
            load_location = path_CMIP6 / "work" / "diagnostic" / "script" 
            CMIP_forcing_object = ewatercycle.forcing.sources["LumpedMakkinkForcing"].load(directory=load_location)
        except:
            if path_CMIP6.exists():
                shutil.rmtree(path_CMIP6)
            path_CMIP6.mkdir(exist_ok=True, parents=True)
            
            CMIP_forcing_object = ewatercycle.forcing.sources["LumpedMakkinkForcing"].generate(
               dataset=cmip_dataset,
               start_time=settings['calibration_start_date'],
               end_time=settings['validation_end_date'],
               directory=path_CMIP6,
               shape=settings['path_shape'],
            )
            
        display(CMIP_forcing_object)
# Out:
# "cmip_dataset = {'dataset': 'MPI-ESM1-2-LR', 'project': 'CMIP6', 'grid': 'gn', 'exp': 'historical', 'ensemble': 'r1i1p1f1'}"
# PosixPath('/project/ewater/Data/ewatercycleClimateImpact/HBV/forcing_data/mexico/hysets_10034/CMIP6/MPI-ESM1-2-LR/historical/r1i1p1f1')
# LumpedMakkinkForcing(start_time='1994-08-01T00:00:00Z', end_time='2014-07-31T00:00:00Z', directory=PosixPath('/project/ewater/Data/ewatercycleClimateImpact/HBV/forcing_data/mexico/hysets_10034/CMIP6/MPI-ESM1-2-LR/historical/r1i1p1f1/work/diagnostic/script'), shape=PosixPath('/project/ewater/Data/ewatercycleClimateImpact/HBV/forcing_data/mexico/hysets_10034/CMIP6/MPI-ESM1-2-LR/historical/r1i1p1f1/work/diagnostic/script/hysets_10034.shp'), filenames={'pr': 'CMIP6_MPI-ESM1-2-LR_day_historical_r1i1p1f1_pr_gn_1994-2014.nc', 'tas': 'CMIP6_MPI-ESM1-2-LR_day_historical_r1i1p1f1_tas_gn_1994-2014.nc', 'rsds': 'CMIP6_MPI-ESM1-2-LR_day_historical_r1i1p1f1_rsds_gn_1994-2014.nc', 'evspsblpot': 'Derived_Makkink_evspsblpot.nc'})

# %%
# Quick plot of the precipitation and potential evaporation data of the last generated forcing
ds_CMIP = xr.open_mfdataset([CMIP_forcing_object['pr'],CMIP_forcing_object['evspsblpot']])
ds_CMIP["pr"].plot(label = 'precipitation')
ds_CMIP["evspsblpot"].plot(label = 'potential evaporation')
plt.legend()
# Out:
# /tmp/ipykernel_309645/2825575744.py:2: FutureWarning: In a future version of xarray the default value for compat will change from compat='no_conflicts' to compat='override'. This is likely to lead to different results when combining overlapping variables with the same name. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set compat explicitly.
# /tmp/ipykernel_309645/2825575744.py:2: FutureWarning: In a future version of xarray the default value for compat will change from compat='no_conflicts' to compat='override'. This is likely to lead to different results when combining overlapping variables with the same name. To opt in to new defaults and get rid of these warnings now use `set_options(use_new_combine_kwarg_defaults=True) or set compat explicitly.

# %% [markdown]
# ## DestinE CMIP6 historical forcing
#
# The DestinE Climate DT provides a CMIP6 historical simulation using the ICON model at ~40 km resolution (HEALPix H128 grid, referred to as "standard" resolution). The historical run covers 1990 to ~2020, overlapping with both the calibration (1994–2004) and validation (2004–2014) periods used in this workflow.
#
# Data is retrieved via the **polytope API**, a request-based interface to the DestinE data portal. The request specifies the CMIP6 historical activity, the ICON model, and the surface variables needed: 2 m temperature (`t2m`), total precipitation (`tp`), and surface solar radiation downwards (`ssrd`).
#
# Because the data arrives on a HEALPix grid (a pixelised sphere, not a regular lat/lon grid), it is first regridded to a 0.5° regular grid using `earthkit.regrid` before being clipped to the catchment shapefile.
#
# > **Note:** If `generate` is slow, this is expected — the polytope API retrieves multi-year GRIB data and the regridding adds processing time. The result is cached to disk so subsequent calls use `load`.

# %%
# %%capture cap
try:
    # %run scripts/desp-authentication.py
except:
    # %run ../scripts/desp-authentication.py

# %%
output_1 = cap.stdout.split('}\n')
access_token = output_1[-1][0:-1]

# %%
# %%time 

# Generate forcing for the calibration + validation period
try:
    DestinE_hist_forcing_object = DestinEHistoricalForcing.load(settings["path_DestinE_historical"])
    print("Loading")
except FileNotFoundError:
# DestinE_hist_forcing_object = DestinEHistoricalForcing.generate(
    print("Generating")
    DestinE_hist_forcing_object = DestinEHistoricalForcing.generate(
        start_time=settings["calibration_start_date"],
        end_time=settings["validation_end_date"],
        directory=settings["path_DestinE_historical"],
        shape=settings["path_shape"],
    )

display(DestinE_hist_forcing_object)
# Out:
# Generating
# Polygon simplified to 200 points (tolerance=0.0010 deg)
# Data is split up in parts
# Running 1 of 21
# start = '19940801'
# end = '19941231'
# 2026-04-16 10:16:39 - INFO - Key read from /home/ewater-mmelotto/.polytopeapirc
# 2026-04-16 10:16:39 - INFO - Sending request...
# {'request': 'activity: CMIP6\n'
#             'class: ng\n'
#             'date: 19940801/to/19941231\n'
#             'experiment: hist\n'
#             "expver: '0001'\n"
#             'feature:\n'
#             '  shape:\n'
#             '  - - 26.052869493999026\n'
#             '    - -108.30612674718223\n'
#             '  - - 26.059405070758707\n'
#             '    - -108.30710676874502\n'
#             '  - - 26.063834663862274\n'
#             '    - -108.30431251158664\n'
#             '  - - 26.070136882773625\n'
#             '    - -108.30355679483931\n'
#             '  - - 26.07244916517976\n'
#             '    - -108.30019779262784\n'
#             '  - - 26.07548607122027\n'
#             '    - -108.29939701171666\n'
#             '  - - 26.082276910907975\n'
#             '    - -108.30257355226478\n'
#             '  - - 26.087750611807277\n'
#             '    - -108.2992939293419\n'
#             '  - - 26.093039308033998\n'
#             '    - -108.30185604965634\n'
#             '  - - 26.098082642368745\n'
#             '    - -108.30160577174648\n'
#             '  - - 26.103924181605343\n'
#             '    - -108.29772447863625\n'
#             '  - - 26.10938275944965\n'
#             '    - -108.29789242724684\n'
#             '  - - 26.117167251749713\n'
#             '    - -108.28848006002873\n'
#             '  - - 26.1265335708004\n'
#             '    - -108.2832234749187\n'
#             '  - - 26.130734824073837\n'
#             '    - -108.28681339296968\n'
#             '  - - 26.134937298351694\n'
#             '    - -108.2824979702812\n'
#             '  - - 26.135403946048136\n'
#             '    - -108.26493032241505\n'
#             '  - - 26.137390301269413\n'
#             '    - -108.25877764004736\n'
#             '  - - 26.14234350727651\n'
#             '    - -108.25963386116007\n'
#             '  - - 26.143248387566132\n'
#             '    - -108.25766232399268\n'
#             '  - - 26.152662042788958\n'
#             '    - -108.26217461939687\n'
#             '  - - 26.16216725134455\n'
#             '    - -108.25298367398374\n'
#             '  - - 26.159728422478334\n'
#             '    - -108.24606418582835\n'
#             '  - - 26.15718339222604\n'
#             '    - -108.24475905108356\n'
#             '  - - 26.155188762974646\n'
#             '    - -108.24099487739913\n'
#             '  - - 26.154920343998864\n'
#             '    - -108.23657315132424\n'
#             '  - - 26.16135087237665\n'
#             '    - -108.23182726107085\n'
#             '  - - 26.161924263461174\n'
#             '    - -108.22572700089368\n'
#             '  - - 26.158772544003277\n'
#             '    - -108.21623789839661\n'
#             '  - - 26.156010499962065\n'
#             '    - -108.21273061564612\n'
#             '  - - 26.158614530428842\n'
#             '    - -108.20306780051754\n'
#             '  - - 26.166056140482393\n'
#             '    - -108.19777337326997\n'
#             '  - - 26.16561912889363\n'
#             '    - -108.19178640150466\n'
#             '  - - 26.170382312209934\n'
#             '    - -108.1890757616503\n'
#             '  - - 26.176603761827664\n'
#             '    - -108.1894460079963\n'
#             '  - - 26.174299074449088\n'
#             '    - -108.18332936975962\n'
#             '  - - 26.17508351130084\n'
#             '    - -108.17587819767135\n'
#             '  - - 26.17235320537497\n'
#             '    - -108.16392670022235\n'
#             '  - - 26.174758126117922\n'
#             '    - -108.16002153502534\n'
#             '  - - 26.181326186995758\n'
#             '    - -108.15499800276261\n'
#             '  - - 26.17724381715453\n'
#             '    - -108.14637142940119\n'
#             '  - - 26.176549372629886\n'
#             '    - -108.14080509116512\n'
#             '  - - 26.179485774305018\n'
#             '    - -108.13816660957308\n'
#             '  - - 26.179359362845442\n'
#             '    - -108.1360467898666\n'
#             '  - - 26.185778363181377\n'
#             '    - -108.13031979404644\n'
#             '  - - 26.184451187356494\n'
#             '    - -108.12605540254349\n'
#             '  - - 26.18134951608055\n'
#             '    - -108.12533376392001\n'
#             '  - - 26.186350466261217\n'
#             '    - -108.12014686106333\n'
#             '  - - 26.181758384566987\n'
#             '    - -108.11779341250752\n'
#             '  - - 26.17985035763047\n'
#             '    - -108.11386512222644\n'
#             '  - - 26.182113540858087\n'
#             '    - -108.11314856962149\n'
#             '  - - 26.186614205219996\n'
#             '    - -108.10527903601223\n'
#             '  - - 26.186305503097735\n'
#             '    - -108.0999348645838\n'
#             '  - - 26.18994753933816\n'
#             '    - -108.0961458028089\n'
#             '  - - 26.189147842430884\n'
#             '    - -108.0954986944564\n'
#             '  - - 26.182775230263637\n'
#             '    - -108.0936624177807\n'
#             '  - - 26.17559471515932\n'
#             '    - -108.09601878134714\n'
#             '  - - 26.16718074757085\n'
#             '    - -108.09540497111566\n'
#             '  - - 26.163980605936896\n'
#             '    - -108.09669661081135\n'
#             '  - - 26.158840022248626\n'
#             '    - -108.09514163815832\n'
#             '  - - 26.153847007096825\n'
#             '    - -108.09877092435238\n'
#             '  - - 26.14573495960593\n'
#             '    - -108.1007102824028\n'
#             '  - - 26.14419578901038\n'
#             '    - -108.1023714564419\n'
#             '  - - 26.13945315376878\n'
#             '    - -108.10043759141148\n'
#             '  - - 26.13689944248494\n'
#             '    - -108.10239010550968\n'
#             '  - - 26.130859267526258\n'
#             '    - -108.10065012918415\n'
#             '  - - 26.12913353325245\n'
#             '    - -108.0995357631329\n'
#             '  - - 26.129178495415875\n'
#             '    - -108.09713830241706\n'
#             '  - - 26.1224324148909\n'
#             '    - -108.0946383023285\n'
#             '  - - 26.12130265478373\n'
#             '    - -108.09224436762547\n'
#             '  - - 26.11665421688462\n'
#             '    - -108.09028615650652\n'
#             '  - - 26.115500109688917\n'
#             '    - -108.08821150296426\n'
#             '  - - 26.11652597541842\n'
#             '    - -108.08586076841827\n'
#             '  - - 26.11496815475504\n'
#             '    - -108.08466610707517\n'
#             '  - - 26.111708537904907\n'
#             '    - -108.08635060919909\n'
#             '  - - 26.107129816259196\n'
#             '    - -108.08265981378138\n'
#             '  - - 26.10571915813085\n'
#             '    - -108.08313487050843\n'
#             '  - - 26.106883709364517\n'
#             '    - -108.08635881522888\n'
#             '  - - 26.1047014984312\n'
#             '    - -108.08795942804784\n'
#             '  - - 26.104748902603546\n'
#             '    - -108.09187876729634\n'
#             '  - - 26.10260982382703\n'
#             '    - -108.0959825672155\n'
#             '  - - 26.099220202504277\n'
#             '    - -108.09465152637658\n'
#             '  - - 26.098748264788576\n'
#             '    - -108.09810442092936\n'
#             '  - - 26.096991198400872\n'
#             '    - -108.09903418930946\n'
#             '  - - 26.09361982014445\n'
#             '    - -108.09793759132286\n'
#             '  - - 26.08527143079436\n'
#             '    - -108.1002960578969\n'
#             '  - - 26.08349883435016\n'
#             '    - -108.0990763034626\n'
#             '  - - 26.07633900432102\n'
#             '    - -108.0996063603896\n'
#             '  - - 26.07275705429906\n'
#             '    - -108.09715410347455\n'
#             '  - - 26.07209699289944\n'
#             '    - -108.09443498758935\n'
#             '  - - 26.067616266610056\n'
#             '    - -108.09369707190672\n'
#             '  - - 26.065225315917864\n'
#             '    - -108.0912603450481\n'
#             '  - - 26.063558648858812\n'
#             '    - -108.0923714560875\n'
#             '  - - 26.063278225839383\n'
#             '    - -108.09763004220478\n'
#             '  - - 26.061392307983223\n'
#             '    - -108.0995994433644\n'
#             '  - - 26.056378811756918\n'
#             '    - -108.1006691862534\n'
#             '  - - 26.05390953278003\n'
#             '    - -108.10413469385207\n'
#             '  - - 26.05044497418481\n'
#             '    - -108.11466509013468\n'
#             '  - - 26.056120904819345\n'
#             '    - -108.11849891107231\n'
#             '  - - 26.05463374941285\n'
#             '    - -108.12466759949825\n'
#             '  - - 26.042541396451835\n'
#             '    - -108.12151940605314\n'
#             '  - - 26.035882596244154\n'
#             '    - -108.13438032680828\n'
#             '  - - 26.03420602814913\n'
#             '    - -108.13349314758301\n'
#             '  - - 26.02833966782231\n'
#             '    - -108.13546871976506\n'
#             '  - - 26.022105808159488\n'
#             '    - -108.13127940153502\n'
#             '  - - 26.01810508961511\n'
#             '    - -108.13071536948455\n'
#             '  - - 26.01052004704013\n'
#             '    - -108.13277754398142\n'
#             '  - - 26.01088090035199\n'
#             '    - -108.13502112813784\n'
#             '  - - 26.00860530607917\n'
#             '    - -108.13649058347998\n'
#             '  - - 26.01052140304506\n'
#             '    - -108.14293067389256\n'
#             '  - - 26.007430582808578\n'
#             '    - -108.14572004903316\n'
#             '  - - 26.01050309297846\n'
#             '    - -108.14971975057387\n'
#             '  - - 26.0053298891716\n'
#             '    - -108.1498690151165\n'
#             '  - - 26.000113960209426\n'
#             '    - -108.14701650374633\n'
#             '  - - 25.997489990670147\n'
#             '    - -108.14849362211635\n'
#             '  - - 25.997132189369374\n'
#             '    - -108.15073998728285\n'
#             '  - - 25.991488403851683\n'
#             '    - -108.15304216565225\n'
#             '  - - 25.987642442869966\n'
#             '    - -108.15241682637888\n'
#             '  - - 25.981936334125738\n'
#             '    - -108.15518049842608\n'
#             '  - - 25.980106364472984\n'
#             '    - -108.15325470342496\n'
#             '  - - 25.972169759619927\n'
#             '    - -108.15293759127212\n'
#             '  - - 25.96926082404467\n'
#             '    - -108.15114492175495\n'
#             '  - - 25.967735894500883\n'
#             '    - -108.15255781789146\n'
#             '  - - 25.971146063898342\n'
#             '    - -108.15631114053643\n'
#             '  - - 25.9698335371267\n'
#             '    - -108.15821855647071\n'
#             '  - - 25.97312333208657\n'
#             '    - -108.1602304117847\n'
#             '  - - 25.972019070072122\n'
#             '    - -108.1655015429476\n'
#             '  - - 25.96902651619285\n'
#             '    - -108.1685026418579\n'
#             '  - - 25.96918595377246\n'
#             '    - -108.1725255364829\n'
#             '  - - 25.965597832728058\n'
#             '    - -108.17014157181615\n'
#             '  - - 25.955325751384514\n'
#             '    - -108.17387610939282\n'
#             '  - - 25.94304012072086\n'
#             '    - -108.18865977313799\n'
#             '  - - 25.943836425615753\n'
#             '    - -108.19387085308254\n'
#             '  - - 25.941100490669434\n'
#             '    - -108.20121517978241\n'
#             '  - - 25.932891668826745\n'
#             '    - -108.2083372026741\n'
#             '  - - 25.929675388134164\n'
#             '    - -108.20653096910767\n'
#             '  - - 25.925624552407548\n'
#             '    - -108.21136698768872\n'
#             '  - - 25.916588907558996\n'
#             '    - -108.20821353922457\n'
#             '  - - 25.91066965003989\n'
#             '    - -108.21664988589441\n'
#             '  - - 25.895277737083514\n'
#             '    - -108.2216137399402\n'
#             '  - - 25.893011161843503\n'
#             '    - -108.22571286084228\n'
#             '  - - 25.88717226761656\n'
#             '    - -108.2265406328516\n'
#             '  - - 25.876869872162832\n'
#             '    - -108.23258745383446\n'
#             '  - - 25.87001772625222\n'
#             '    - -108.2340305620808\n'
#             '  - - 25.864955470848713\n'
#             '    - -108.23097361696743\n'
#             '  - - 25.854904676309673\n'
#             '    - -108.2304344390073\n'
#             '  - - 25.854361191333844\n'
#             '    - -108.23660533044125\n'
#             '  - - 25.845124130753046\n'
#             '    - -108.24610436797438\n'
#             '  - - 25.843913804353004\n'
#             '    - -108.24971225709065\n'
#             '  - - 25.844579154771843\n'
#             '    - -108.26218163842236\n'
#             '  - - 25.842852809495806\n'
#             '    - -108.26502841977168\n'
#             '  - - 25.838234753707123\n'
#             '    - -108.26599036726877\n'
#             '  - - 25.835805079874202\n'
#             '    - -108.26851922346229\n'
#             '  - - 25.833153645235083\n'
#             '    - -108.2910645254244\n'
#             '  - - 25.823158052896698\n'
#             '    - -108.2949596535849\n'
#             '  - - 25.813182331630507\n'
#             '    - -108.304425934999\n'
#             '  - - 25.80282893799136\n'
#             '    - -108.31925110389504\n'
#             '  - - 25.797967555318106\n'
#             '    - -108.32015174516926\n'
#             '  - - 25.78479610043405\n'
#             '    - -108.31876841714028\n'
#             '  - - 25.775974214362638\n'
#             '    - -108.32969069284756\n'
#             '  - - 25.76812794183797\n'
#             '    - -108.33000173397835\n'
#             '  - - 25.76577123927029\n'
#             '    - -108.33183306063601\n'
#             '  - - 25.75800560003881\n'
#             '    - -108.3426517449667\n'
#             '  - - 25.757733383049185\n'
#             '    - -108.35124786921737\n'
#             '  - - 25.764055134031533\n'
#             '    - -108.34645223478314\n'
#             '  - - 25.772901094190495\n'
#             '    - -108.3474435133869\n'
#             '  - - 25.781489080411568\n'
#             '    - -108.35942461294347\n'
#             '  - - 25.79807958872538\n'
#             '    - -108.36150686151335\n'
#             '  - - 25.835788939815526\n'
#             '    - -108.36043508461698\n'
#             '  - - 25.852188204434068\n'
#             '    - -108.35709073045875\n'
#             '  - - 25.86359262389419\n'
#             '    - -108.36015537360008\n'
#             '  - - 25.898479437723093\n'
#             '    - -108.36042952359672\n'
#             '  - - 25.91495560662127\n'
#             '    - -108.35904619556776\n'
#             '  - - 25.917733384719725\n'
#             '    - -108.35849063954805\n'
#             '  - - 25.919752767061016\n'
#             '    - -108.35530589297007\n'
#             '  - - 25.925825968139797\n'
#             '    - -108.35205950116801\n'
#             '  - - 25.941721828928276\n'
#             '    - -108.33266120564667\n'
#             '  - - 25.94384449564512\n'
#             '    - -108.33182397260299\n'
#             '  - - 25.947052843308875\n'
#             '    - -108.32409858351774\n'
#             '  - - 25.950549479020644\n'
#             '    - -108.32317424015734\n'
#             '  - - 25.953457533592704\n'
#             '    - -108.31939287441041\n'
#             '  - - 25.957498264282545\n'
#             '    - -108.31848022909259\n'
#             '  - - 25.960505602215555\n'
#             '    - -108.31265174490346\n'
#             '  - - 25.970682265212243\n'
#             '    - -108.31181481786085\n'
#             '  - - 25.9747982041755\n'
#             '    - -108.30980910056923\n'
#             '  - - 25.975880086108585\n'
#             '    - -108.30752289325784\n'
#             '  - - 25.98072085270689\n'
#             '    - -108.30654619470708\n'
#             '  - - 25.984727810273963\n'
#             '    - -108.30934808189316\n'
#             '  - - 25.989456611465236\n'
#             '    - -108.3102712382493\n'
#             '  - - 25.995920844965603\n'
#             '    - -108.30714423788123\n'
#             '  - - 26.003985623284617\n'
#             '    - -108.30766028975732\n'
#             '  - - 26.022204210517195\n'
#             '    - -108.30346859851868\n'
#             '  - - 26.029208062979308\n'
#             '    - -108.30401042148843\n'
#             '  - - 26.033600694948454\n'
#             '    - -108.30098239948022\n'
#             '  - - 26.033642674101085\n'
#             '    - -108.29626841734284\n'
#             '  - - 26.038252184858663\n'
#             '    - -108.30015805148336\n'
#             '  - - 26.041066583090235\n'
#             '    - -108.29792386036108\n'
#             '  - - 26.051346056460652\n'
#             '    - -108.29928606331333\n'
#             '  - - 26.053503513303948\n'
#             '    - -108.30153154647665\n'
#             '  - - 26.052869493999026\n'
#             '    - -108.30612674718223\n'
#             '  type: polygon\n'
#             "generation: '1'\n"
#             'levtype: sfc\n'
#             'model: IFS-FESOM\n'
#             'param: 167/260048/169\n'
#             "realization: '1'\n"
#             'resolution: high\n'
#             'stream: clte\n'
#             'time: '
#             '0000/0100/0200/0300/0400/0500/0600/0700/0800/0900/1000/1100/1200/1300/1400/1500/1600/1700/1800/1900/2000/2100/2200/2300\n'
#             'type: fc\n',
#  'verb': 'retrieve'}
# 2026-04-16 10:16:39 - INFO - Polytope user key found in session cache for user ewater-mmelotto
# 2026-04-16 10:16:41 - INFO - Request accepted. Please poll ./4ae3aa49-9670-4f2f-bd5a-319ef065927c for status
# 2026-04-16 10:16:41 - INFO - Polytope user key found in session cache for user ewater-mmelotto
# 2026-04-16 10:16:41 - INFO - Checking request status (4ae3aa49-9670-4f2f-bd5a-319ef065927c)...
# 2026-04-16 10:16:42 - INFO - The current status of the request is 'processing'
# 2026-04-16 10:16:55 - INFO - The current status of the request is 'processed'
# 4ae3aa49-9670-4f2f-bd5a-319ef065927c.covjson:   0%|          | 0.00/3.60M [00:00<?, ?B/s]
# 4ae3aa49-9670-4f2f-bd5a-319ef065927c.covjson:  28%|██▊       | 1.00M/3.60M [00:00<00:01, 2.26MB/s]
# 2026-04-16 10:17:01 - INFO - Key read from /home/ewater-mmelotto/.polytopeapirc
# 2026-04-16 10:17:01 - INFO - Sending request...
# {'request': 'activity: CMIP6\n'
#             'class: ng\n'
#             'date: 19950101/to/19951231\n'
#             'experiment: hist\n'
#             "expver: '0001'\n"
#             'feature:\n'
#             '  shape:\n'
#             '  - - 26.052869493999026\n'
#             '    - -108.30612674718223\n'
#             '  - - 26.059405070758707\n'
#             '    - -108.30710676874502\n'
#             '  - - 26.063834663862274\n'
#             '    - -108.30431251158664\n'
#             '  - - 26.070136882773625\n'
#             '    - -108.30355679483931\n'
#             '  - - 26.07244916517976\n'
#             '    - -108.30019779262784\n'
#             '  - - 26.07548607122027\n'
#             '    - -108.29939701171666\n'
#             '  - - 26.082276910907975\n'
#             '    - -108.30257355226478\n'
#             '  - - 26.087750611807277\n'
#             '    - -108.2992939293419\n'
#             '  - - 26.093039308033998\n'
#             '    - -108.30185604965634\n'
#             '  - - 26.098082642368745\n'
#             '    - -108.30160577174648\n'
#             '  - - 26.103924181605343\n'
#             '    - -108.29772447863625\n'
#             '  - - 26.10938275944965\n'
#             '    - -108.29789242724684\n'
#             '  - - 26.117167251749713\n'
#             '    - -108.28848006002873\n'
#             '  - - 26.1265335708004\n'
#             '    - -108.2832234749187\n'
#             '  - - 26.130734824073837\n'
#             '    - -108.28681339296968\n'
#             '  - - 26.134937298351694\n'
#             '    - -108.2824979702812\n'
#             '  - - 26.135403946048136\n'
#             '    - -108.26493032241505\n'
#             '  - - 26.137390301269413\n'
#             '    - -108.25877764004736\n'
#             '  - - 26.14234350727651\n'
#             '    - -108.25963386116007\n'
#             '  - - 26.143248387566132\n'
#             '    - -108.25766232399268\n'
#             '  - - 26.152662042788958\n'
#             '    - -108.26217461939687\n'
#             '  - - 26.16216725134455\n'
#             '    - -108.25298367398374\n'
#             '  - - 26.159728422478334\n'
#             '    - -108.24606418582835\n'
#             '  - - 26.15718339222604\n'
#             '    - -108.24475905108356\n'
#             '  - - 26.155188762974646\n'
#             '    - -108.24099487739913\n'
#             '  - - 26.154920343998864\n'
#             '    - -108.23657315132424\n'
#             '  - - 26.16135087237665\n'
#             '    - -108.23182726107085\n'
#             '  - - 26.161924263461174\n'
#             '    - -108.22572700089368\n'
#             '  - - 26.158772544003277\n'
#             '    - -108.21623789839661\n'
#             '  - - 26.156010499962065\n'
#             '    - -108.21273061564612\n'
#             '  - - 26.158614530428842\n'
#             '    - -108.20306780051754\n'
#             '  - - 26.166056140482393\n'
#             '    - -108.19777337326997\n'
#             '  - - 26.16561912889363\n'
#             '    - -108.19178640150466\n'
#             '  - - 26.170382312209934\n'
#             '    - -108.1890757616503\n'
#             '  - - 26.176603761827664\n'
#             '    - -108.1894460079963\n'
#             '  - - 26.174299074449088\n'
#             '    - -108.18332936975962\n'
#             '  - - 26.17508351130084\n'
#             '    - -108.17587819767135\n'
#             '  - - 26.17235320537497\n'
#             '    - -108.16392670022235\n'
#             '  - - 26.174758126117922\n'
#             '    - -108.16002153502534\n'
#             '  - - 26.181326186995758\n'
#             '    - -108.15499800276261\n'
#             '  - - 26.17724381715453\n'
#             '    - -108.14637142940119\n'
#             '  - - 26.176549372629886\n'
#             '    - -108.14080509116512\n'
#             '  - - 26.179485774305018\n'
#             '    - -108.13816660957308\n'
#             '  - - 26.179359362845442\n'
#             '    - -108.1360467898666\n'
#             '  - - 26.185778363181377\n'
#             '    - -108.13031979404644\n'
#             '  - - 26.184451187356494\n'
#             '    - -108.12605540254349\n'
#             '  - - 26.18134951608055\n'
#             '    - -108.12533376392001\n'
#             '  - - 26.186350466261217\n'
#             '    - -108.12014686106333\n'
#             '  - - 26.181758384566987\n'
#             '    - -108.11779341250752\n'
#             '  - - 26.17985035763047\n'
#             '    - -108.11386512222644\n'
#             '  - - 26.182113540858087\n'
#             '    - -108.11314856962149\n'
#             '  - - 26.186614205219996\n'
#             '    - -108.10527903601223\n'
#             '  - - 26.186305503097735\n'
#             '    - -108.0999348645838\n'
#             '  - - 26.18994753933816\n'
#             '    - -108.0961458028089\n'
#             '  - - 26.189147842430884\n'
#             '    - -108.0954986944564\n'
#             '  - - 26.182775230263637\n'
#             '    - -108.0936624177807\n'
#             '  - - 26.17559471515932\n'
#             '    - -108.09601878134714\n'
#             '  - - 26.16718074757085\n'
#             '    - -108.09540497111566\n'
#             '  - - 26.163980605936896\n'
#             '    - -108.09669661081135\n'
#             '  - - 26.158840022248626\n'
#             '    - -108.09514163815832\n'
#             '  - - 26.153847007096825\n'
#             '    - -108.09877092435238\n'
#             '  - - 26.14573495960593\n'
#             '    - -108.1007102824028\n'
#             '  - - 26.14419578901038\n'
#             '    - -108.1023714564419\n'
#             '  - - 26.13945315376878\n'
#             '    - -108.10043759141148\n'
#             '  - - 26.13689944248494\n'
#             '    - -108.10239010550968\n'
#             '  - - 26.130859267526258\n'
#             '    - -108.10065012918415\n'
#             '  - - 26.12913353325245\n'
#             '    - -108.0995357631329\n'
#             '  - - 26.129178495415875\n'
#             '    - -108.09713830241706\n'
#             '  - - 26.1224324148909\n'
#             '    - -108.0946383023285\n'
#             '  - - 26.12130265478373\n'
#             '    - -108.09224436762547\n'
#             '  - - 26.11665421688462\n'
#             '    - -108.09028615650652\n'
#             '  - - 26.115500109688917\n'
#             '    - -108.08821150296426\n'
#             '  - - 26.11652597541842\n'
#             '    - -108.08586076841827\n'
#             '  - - 26.11496815475504\n'
#             '    - -108.08466610707517\n'
#             '  - - 26.111708537904907\n'
#             '    - -108.08635060919909\n'
#             '  - - 26.107129816259196\n'
#             '    - -108.08265981378138\n'
#             '  - - 26.10571915813085\n'
#             '    - -108.08313487050843\n'
#             '  - - 26.106883709364517\n'
#             '    - -108.08635881522888\n'
#             '  - - 26.1047014984312\n'
#             '    - -108.08795942804784\n'
#             '  - - 26.104748902603546\n'
#             '    - -108.09187876729634\n'
#             '  - - 26.10260982382703\n'
#             '    - -108.0959825672155\n'
#             '  - - 26.099220202504277\n'
#             '    - -108.09465152637658\n'
#             '  - - 26.098748264788576\n'
#             '    - -108.09810442092936\n'
#             '  - - 26.096991198400872\n'
#             '    - -108.09903418930946\n'
#             '  - - 26.09361982014445\n'
#             '    - -108.09793759132286\n'
#             '  - - 26.08527143079436\n'
#             '    - -108.1002960578969\n'
#             '  - - 26.08349883435016\n'
#             '    - -108.0990763034626\n'
#             '  - - 26.07633900432102\n'
#             '    - -108.0996063603896\n'
#             '  - - 26.07275705429906\n'
#             '    - -108.09715410347455\n'
#             '  - - 26.07209699289944\n'
#             '    - -108.09443498758935\n'
#             '  - - 26.067616266610056\n'
#             '    - -108.09369707190672\n'
#             '  - - 26.065225315917864\n'
#             '    - -108.0912603450481\n'
#             '  - - 26.063558648858812\n'
#             '    - -108.0923714560875\n'
#             '  - - 26.063278225839383\n'
#             '    - -108.09763004220478\n'
#             '  - - 26.061392307983223\n'
#             '    - -108.0995994433644\n'
#             '  - - 26.056378811756918\n'
#             '    - -108.1006691862534\n'
#             '  - - 26.05390953278003\n'
#             '    - -108.10413469385207\n'
#             '  - - 26.05044497418481\n'
#             '    - -108.11466509013468\n'
#             '  - - 26.056120904819345\n'
#             '    - -108.11849891107231\n'
#             '  - - 26.05463374941285\n'
#             '    - -108.12466759949825\n'
#             '  - - 26.042541396451835\n'
#             '    - -108.12151940605314\n'
#             '  - - 26.035882596244154\n'
#             '    - -108.13438032680828\n'
#             '  - - 26.03420602814913\n'
#             '    - -108.13349314758301\n'
#             '  - - 26.02833966782231\n'
#             '    - -108.13546871976506\n'
#             '  - - 26.022105808159488\n'
#             '    - -108.13127940153502\n'
#             '  - - 26.01810508961511\n'
#             '    - -108.13071536948455\n'
#             '  - - 26.01052004704013\n'
#             '    - -108.13277754398142\n'
#             '  - - 26.01088090035199\n'
#             '    - -108.13502112813784\n'
#             '  - - 26.00860530607917\n'
#             '    - -108.13649058347998\n'
#             '  - - 26.01052140304506\n'
#             '    - -108.14293067389256\n'
#             '  - - 26.007430582808578\n'
#             '    - -108.14572004903316\n'
#             '  - - 26.01050309297846\n'
#             '    - -108.14971975057387\n'
#             '  - - 26.0053298891716\n'
#             '    - -108.1498690151165\n'
#             '  - - 26.000113960209426\n'
#             '    - -108.14701650374633\n'
#             '  - - 25.997489990670147\n'
#             '    - -108.14849362211635\n'
#             '  - - 25.997132189369374\n'
#             '    - -108.15073998728285\n'
#             '  - - 25.991488403851683\n'
#             '    - -108.15304216565225\n'
#             '  - - 25.987642442869966\n'
#             '    - -108.15241682637888\n'
#             '  - - 25.981936334125738\n'
#             '    - -108.15518049842608\n'
#             '  - - 25.980106364472984\n'
#             '    - -108.15325470342496\n'
#             '  - - 25.972169759619927\n'
#             '    - -108.15293759127212\n'
#             '  - - 25.96926082404467\n'
#             '    - -108.15114492175495\n'
#             '  - - 25.967735894500883\n'
#             '    - -108.15255781789146\n'
#             '  - - 25.971146063898342\n'
#             '    - -108.15631114053643\n'
#             '  - - 25.9698335371267\n'
#             '    - -108.15821855647071\n'
#             '  - - 25.97312333208657\n'
#             '    - -108.1602304117847\n'
#             '  - - 25.972019070072122\n'
#             '    - -108.1655015429476\n'
#             '  - - 25.96902651619285\n'
#             '    - -108.1685026418579\n'
#             '  - - 25.96918595377246\n'
#             '    - -108.1725255364829\n'
#             '  - - 25.965597832728058\n'
#             '    - -108.17014157181615\n'
#             '  - - 25.955325751384514\n'
#             '    - -108.17387610939282\n'
#             '  - - 25.94304012072086\n'
#             '    - -108.18865977313799\n'
#             '  - - 25.943836425615753\n'
#             '    - -108.19387085308254\n'
#             '  - - 25.941100490669434\n'
#             '    - -108.20121517978241\n'
#             '  - - 25.932891668826745\n'
#             '    - -108.2083372026741\n'
#             '  - - 25.929675388134164\n'
#             '    - -108.20653096910767\n'
#             '  - - 25.925624552407548\n'
#             '    - -108.21136698768872\n'
#             '  - - 25.916588907558996\n'
#             '    - -108.20821353922457\n'
#             '  - - 25.91066965003989\n'
#             '    - -108.21664988589441\n'
#             '  - - 25.895277737083514\n'
#             '    - -108.2216137399402\n'
#             '  - - 25.893011161843503\n'
#             '    - -108.22571286084228\n'
#             '  - - 25.88717226761656\n'
#             '    - -108.2265406328516\n'
#             '  - - 25.876869872162832\n'
#             '    - -108.23258745383446\n'
#             '  - - 25.87001772625222\n'
#             '    - -108.2340305620808\n'
#             '  - - 25.864955470848713\n'
#             '    - -108.23097361696743\n'
#             '  - - 25.854904676309673\n'
#             '    - -108.2304344390073\n'
#             '  - - 25.854361191333844\n'
#             '    - -108.23660533044125\n'
#             '  - - 25.845124130753046\n'
#             '    - -108.24610436797438\n'
#             '  - - 25.843913804353004\n'
#             '    - -108.24971225709065\n'
#             '  - - 25.844579154771843\n'
#             '    - -108.26218163842236\n'
#             '  - - 25.842852809495806\n'
#             '    - -108.26502841977168\n'
#             '  - - 25.838234753707123\n'
#             '    - -108.26599036726877\n'
#             '  - - 25.835805079874202\n'
#             '    - -108.26851922346229\n'
#             '  - - 25.833153645235083\n'
#             '    - -108.2910645254244\n'
#             '  - - 25.823158052896698\n'
#             '    - -108.2949596535849\n'
#             '  - - 25.813182331630507\n'
#             '    - -108.304425934999\n'
#             '  - - 25.80282893799136\n'
#             '    - -108.31925110389504\n'
#             '  - - 25.797967555318106\n'
#             '    - -108.32015174516926\n'
#             '  - - 25.78479610043405\n'
#             '    - -108.31876841714028\n'
#             '  - - 25.775974214362638\n'
#             '    - -108.32969069284756\n'
#             '  - - 25.76812794183797\n'
#             '    - -108.33000173397835\n'
#             '  - - 25.76577123927029\n'
#             '    - -108.33183306063601\n'
#             '  - - 25.75800560003881\n'
#             '    - -108.3426517449667\n'
#             '  - - 25.757733383049185\n'
#             '    - -108.35124786921737\n'
#             '  - - 25.764055134031533\n'
#             '    - -108.34645223478314\n'
#             '  - - 25.772901094190495\n'
#             '    - -108.3474435133869\n'
#             '  - - 25.781489080411568\n'
#             '    - -108.35942461294347\n'
#             '  - - 25.79807958872538\n'
#             '    - -108.36150686151335\n'
#             '  - - 25.835788939815526\n'
#             '    - -108.36043508461698\n'
#             '  - - 25.852188204434068\n'
#             '    - -108.35709073045875\n'
#             '  - - 25.86359262389419\n'
#             '    - -108.36015537360008\n'
#             '  - - 25.898479437723093\n'
#             '    - -108.36042952359672\n'
#             '  - - 25.91495560662127\n'
#             '    - -108.35904619556776\n'
#             '  - - 25.917733384719725\n'
#             '    - -108.35849063954805\n'
#             '  - - 25.919752767061016\n'
#             '    - -108.35530589297007\n'
#             '  - - 25.925825968139797\n'
#             '    - -108.35205950116801\n'
#             '  - - 25.941721828928276\n'
#             '    - -108.33266120564667\n'
#             '  - - 25.94384449564512\n'
#             '    - -108.33182397260299\n'
#             '  - - 25.947052843308875\n'
#             '    - -108.32409858351774\n'
#             '  - - 25.950549479020644\n'
#             '    - -108.32317424015734\n'
#             '  - - 25.953457533592704\n'
#             '    - -108.31939287441041\n'
#             '  - - 25.957498264282545\n'
#             '    - -108.31848022909259\n'
#             '  - - 25.960505602215555\n'
#             '    - -108.31265174490346\n'
#             '  - - 25.970682265212243\n'
#             '    - -108.31181481786085\n'
#             '  - - 25.9747982041755\n'
#             '    - -108.30980910056923\n'
#             '  - - 25.975880086108585\n'
#             '    - -108.30752289325784\n'
#             '  - - 25.98072085270689\n'
#             '    - -108.30654619470708\n'
#             '  - - 25.984727810273963\n'
#             '    - -108.30934808189316\n'
#             '  - - 25.989456611465236\n'
#             '    - -108.3102712382493\n'
#             '  - - 25.995920844965603\n'
#             '    - -108.30714423788123\n'
#             '  - - 26.003985623284617\n'
#             '    - -108.30766028975732\n'
#             '  - - 26.022204210517195\n'
#             '    - -108.30346859851868\n'
#             '  - - 26.029208062979308\n'
#             '    - -108.30401042148843\n'
#             '  - - 26.033600694948454\n'
#             '    - -108.30098239948022\n'
#             '  - - 26.033642674101085\n'
#             '    - -108.29626841734284\n'
#             '  - - 26.038252184858663\n'
#             '    - -108.30015805148336\n'
#             '  - - 26.041066583090235\n'
#             '    - -108.29792386036108\n'
#             '  - - 26.051346056460652\n'
#             '    - -108.29928606331333\n'
#             '  - - 26.053503513303948\n'
#             '    - -108.30153154647665\n'
#             '  - - 26.052869493999026\n'
#             '    - -108.30612674718223\n'
#             '  type: polygon\n'
#             "generation: '1'\n"
#             'levtype: sfc\n'
#             'model: IFS-FESOM\n'
#             'param: 167/260048/169\n'
#             "realization: '1'\n"
#             'resolution: high\n'
#             'stream: clte\n'
#             'time: '
#             '0000/0100/0200/0300/0400/0500/0600/0700/0800/0900/1000/1100/1200/1300/1400/1500/1600/1700/1800/1900/2000/2100/2200/2300\n'
#             'type: fc\n',
#  'verb': 'retrieve'}
# 2026-04-16 10:17:01 - INFO - Polytope user key found in session cache for user ewater-mmelotto
# Data is split up in parts
# Running 2 of 21
# start = '19950101'
# end = '19951231'
# 2026-04-16 10:17:01 - INFO - Request accepted. Please poll ./fa7cebc4-68de-47cf-ac68-9a601b6479fe for status
# 2026-04-16 10:17:01 - INFO - Polytope user key found in session cache for user ewater-mmelotto
# 2026-04-16 10:17:01 - INFO - Checking request status (fa7cebc4-68de-47cf-ac68-9a601b6479fe)...
# 2026-04-16 10:17:01 - INFO - The current status of the request is 'processing'
# 2026-04-16 10:17:22 - INFO - The current status of the request is 'processed'
# fa7cebc4-68de-47cf-ac68-9a601b6479fe.covjson:   0%|          | 0.00/8.51M [00:00<?, ?B/s]
# fa7cebc4-68de-47cf-ac68-9a601b6479fe.covjson:  12%|█▏        | 1.00M/8.51M [00:00<00:03, 2.25MB/s]
# fa7cebc4-68de-47cf-ac68-9a601b6479fe.covjson:  71%|███████   | 6.00M/8.51M [00:00<00:00, 12.9MB/s]
# 2026-04-16 10:17:24 - INFO - Key read from /home/ewater-mmelotto/.polytopeapirc
# 2026-04-16 10:17:24 - INFO - Sending request...
# {'request': 'activity: CMIP6\n'
#             'class: ng\n'
#             'date: 19960101/to/19961231\n'
#             'experiment: hist\n'
#             "expver: '0001'\n"
#             'feature:\n'
#             '  shape:\n'
#             '  - - 26.052869493999026\n'
#             '    - -108.30612674718223\n'
#             '  - - 26.059405070758707\n'
#             '    - -108.30710676874502\n'
#             '  - - 26.063834663862274\n'
#             '    - -108.30431251158664\n'
#             '  - - 26.070136882773625\n'
#             '    - -108.30355679483931\n'
#             '  - - 26.07244916517976\n'
#             '    - -108.30019779262784\n'
#             '  - - 26.07548607122027\n'
#             '    - -108.29939701171666\n'
#             '  - - 26.082276910907975\n'
#             '    - -108.30257355226478\n'
#             '  - - 26.087750611807277\n'
#             '    - -108.2992939293419\n'
#             '  - - 26.093039308033998\n'
#             '    - -108.30185604965634\n'
#             '  - - 26.098082642368745\n'
#             '    - -108.30160577174648\n'
#             '  - - 26.103924181605343\n'
#             '    - -108.29772447863625\n'
#             '  - - 26.10938275944965\n'
#             '    - -108.29789242724684\n'
#             '  - - 26.117167251749713\n'
#             '    - -108.28848006002873\n'
#             '  - - 26.1265335708004\n'
#             '    - -108.2832234749187\n'
#             '  - - 26.130734824073837\n'
#             '    - -108.28681339296968\n'
#             '  - - 26.134937298351694\n'
#             '    - -108.2824979702812\n'
#             '  - - 26.135403946048136\n'
#             '    - -108.26493032241505\n'
#             '  - - 26.137390301269413\n'
#             '    - -108.25877764004736\n'
#             '  - - 26.14234350727651\n'
#             '    - -108.25963386116007\n'
#             '  - - 26.143248387566132\n'
#             '    - -108.25766232399268\n'
#             '  - - 26.152662042788958\n'
#             '    - -108.26217461939687\n'
#             '  - - 26.16216725134455\n'
#             '    - -108.25298367398374\n'
#             '  - - 26.159728422478334\n'
#             '    - -108.24606418582835\n'
#             '  - - 26.15718339222604\n'
#             '    - -108.24475905108356\n'
#             '  - - 26.155188762974646\n'
#             '    - -108.24099487739913\n'
#             '  - - 26.154920343998864\n'
#             '    - -108.23657315132424\n'
#             '  - - 26.16135087237665\n'
#             '    - -108.23182726107085\n'
#             '  - - 26.161924263461174\n'
#             '    - -108.22572700089368\n'
#             '  - - 26.158772544003277\n'
#             '    - -108.21623789839661\n'
#             '  - - 26.156010499962065\n'
#             '    - -108.21273061564612\n'
#             '  - - 26.158614530428842\n'
#             '    - -108.20306780051754\n'
#             '  - - 26.166056140482393\n'
#             '    - -108.19777337326997\n'
#             '  - - 26.16561912889363\n'
#             '    - -108.19178640150466\n'
#             '  - - 26.170382312209934\n'
#             '    - -108.1890757616503\n'
#             '  - - 26.176603761827664\n'
#             '    - -108.1894460079963\n'
#             '  - - 26.174299074449088\n'
#             '    - -108.18332936975962\n'
#             '  - - 26.17508351130084\n'
#             '    - -108.17587819767135\n'
#             '  - - 26.17235320537497\n'
#             '    - -108.16392670022235\n'
#             '  - - 26.174758126117922\n'
#             '    - -108.16002153502534\n'
#             '  - - 26.181326186995758\n'
#             '    - -108.15499800276261\n'
#             '  - - 26.17724381715453\n'
#             '    - -108.14637142940119\n'
#             '  - - 26.176549372629886\n'
#             '    - -108.14080509116512\n'
#             '  - - 26.179485774305018\n'
#             '    - -108.13816660957308\n'
#             '  - - 26.179359362845442\n'
#             '    - -108.1360467898666\n'
#             '  - - 26.185778363181377\n'
#             '    - -108.13031979404644\n'
#             '  - - 26.184451187356494\n'
#             '    - -108.12605540254349\n'
#             '  - - 26.18134951608055\n'
#             '    - -108.12533376392001\n'
#             '  - - 26.186350466261217\n'
#             '    - -108.12014686106333\n'
#             '  - - 26.181758384566987\n'
#             '    - -108.11779341250752\n'
#             '  - - 26.17985035763047\n'
#             '    - -108.11386512222644\n'
#             '  - - 26.182113540858087\n'
#             '    - -108.11314856962149\n'
#             '  - - 26.186614205219996\n'
#             '    - -108.10527903601223\n'
#             '  - - 26.186305503097735\n'
#             '    - -108.0999348645838\n'
#             '  - - 26.18994753933816\n'
#             '    - -108.0961458028089\n'
#             '  - - 26.189147842430884\n'
#             '    - -108.0954986944564\n'
#             '  - - 26.182775230263637\n'
#             '    - -108.0936624177807\n'
#             '  - - 26.17559471515932\n'
#             '    - -108.09601878134714\n'
#             '  - - 26.16718074757085\n'
#             '    - -108.09540497111566\n'
#             '  - - 26.163980605936896\n'
#             '    - -108.09669661081135\n'
#             '  - - 26.158840022248626\n'
#             '    - -108.09514163815832\n'
#             '  - - 26.153847007096825\n'
#             '    - -108.09877092435238\n'
#             '  - - 26.14573495960593\n'
#             '    - -108.1007102824028\n'
#             '  - - 26.14419578901038\n'
#             '    - -108.1023714564419\n'
#             '  - - 26.13945315376878\n'
#             '    - -108.10043759141148\n'
#             '  - - 26.13689944248494\n'
#             '    - -108.10239010550968\n'
#             '  - - 26.130859267526258\n'
#             '    - -108.10065012918415\n'
#             '  - - 26.12913353325245\n'
#             '    - -108.0995357631329\n'
#             '  - - 26.129178495415875\n'
#             '    - -108.09713830241706\n'
#             '  - - 26.1224324148909\n'
#             '    - -108.0946383023285\n'
#             '  - - 26.12130265478373\n'
#             '    - -108.09224436762547\n'
#             '  - - 26.11665421688462\n'
#             '    - -108.09028615650652\n'
#             '  - - 26.115500109688917\n'
#             '    - -108.08821150296426\n'
#             '  - - 26.11652597541842\n'
#             '    - -108.08586076841827\n'
#             '  - - 26.11496815475504\n'
#             '    - -108.08466610707517\n'
#             '  - - 26.111708537904907\n'
#             '    - -108.08635060919909\n'
#             '  - - 26.107129816259196\n'
#             '    - -108.08265981378138\n'
#             '  - - 26.10571915813085\n'
#             '    - -108.08313487050843\n'
#             '  - - 26.106883709364517\n'
#             '    - -108.08635881522888\n'
#             '  - - 26.1047014984312\n'
#             '    - -108.08795942804784\n'
#             '  - - 26.104748902603546\n'
#             '    - -108.09187876729634\n'
#             '  - - 26.10260982382703\n'
#             '    - -108.0959825672155\n'
#             '  - - 26.099220202504277\n'
#             '    - -108.09465152637658\n'
#             '  - - 26.098748264788576\n'
#             '    - -108.09810442092936\n'
#             '  - - 26.096991198400872\n'
#             '    - -108.09903418930946\n'
#             '  - - 26.09361982014445\n'
#             '    - -108.09793759132286\n'
#             '  - - 26.08527143079436\n'
#             '    - -108.1002960578969\n'
#             '  - - 26.08349883435016\n'
#             '    - -108.0990763034626\n'
#             '  - - 26.07633900432102\n'
#             '    - -108.0996063603896\n'
#             '  - - 26.07275705429906\n'
#             '    - -108.09715410347455\n'
#             '  - - 26.07209699289944\n'
#             '    - -108.09443498758935\n'
#             '  - - 26.067616266610056\n'
#             '    - -108.09369707190672\n'
#             '  - - 26.065225315917864\n'
#             '    - -108.0912603450481\n'
#             '  - - 26.063558648858812\n'
#             '    - -108.0923714560875\n'
#             '  - - 26.063278225839383\n'
#             '    - -108.09763004220478\n'
#             '  - - 26.061392307983223\n'
#             '    - -108.0995994433644\n'
#             '  - - 26.056378811756918\n'
#             '    - -108.1006691862534\n'
#             '  - - 26.05390953278003\n'
#             '    - -108.10413469385207\n'
#             '  - - 26.05044497418481\n'
#             '    - -108.11466509013468\n'
#             '  - - 26.056120904819345\n'
#             '    - -108.11849891107231\n'
#             '  - - 26.05463374941285\n'
#             '    - -108.12466759949825\n'
#             '  - - 26.042541396451835\n'
#             '    - -108.12151940605314\n'
#             '  - - 26.035882596244154\n'
#             '    - -108.13438032680828\n'
#             '  - - 26.03420602814913\n'
#             '    - -108.13349314758301\n'
#             '  - - 26.02833966782231\n'
#             '    - -108.13546871976506\n'
#             '  - - 26.022105808159488\n'
#             '    - -108.13127940153502\n'
#             '  - - 26.01810508961511\n'
#             '    - -108.13071536948455\n'
#             '  - - 26.01052004704013\n'
#             '    - -108.13277754398142\n'
#             '  - - 26.01088090035199\n'
#             '    - -108.13502112813784\n'
#             '  - - 26.00860530607917\n'
#             '    - -108.13649058347998\n'
#             '  - - 26.01052140304506\n'
#             '    - -108.14293067389256\n'
#             '  - - 26.007430582808578\n'
#             '    - -108.14572004903316\n'
#             '  - - 26.01050309297846\n'
#             '    - -108.14971975057387\n'
#             '  - - 26.0053298891716\n'
#             '    - -108.1498690151165\n'
#             '  - - 26.000113960209426\n'
#             '    - -108.14701650374633\n'
#             '  - - 25.997489990670147\n'
#             '    - -108.14849362211635\n'
#             '  - - 25.997132189369374\n'
#             '    - -108.15073998728285\n'
#             '  - - 25.991488403851683\n'
#             '    - -108.15304216565225\n'
#             '  - - 25.987642442869966\n'
#             '    - -108.15241682637888\n'
#             '  - - 25.981936334125738\n'
#             '    - -108.15518049842608\n'
#             '  - - 25.980106364472984\n'
#             '    - -108.15325470342496\n'
#             '  - - 25.972169759619927\n'
#             '    - -108.15293759127212\n'
#             '  - - 25.96926082404467\n'
#             '    - -108.15114492175495\n'
#             '  - - 25.967735894500883\n'
#             '    - -108.15255781789146\n'
#             '  - - 25.971146063898342\n'
#             '    - -108.15631114053643\n'
#             '  - - 25.9698335371267\n'
#             '    - -108.15821855647071\n'
#             '  - - 25.97312333208657\n'
#             '    - -108.1602304117847\n'
#             '  - - 25.972019070072122\n'
#             '    - -108.1655015429476\n'
#             '  - - 25.96902651619285\n'
#             '    - -108.1685026418579\n'
#             '  - - 25.96918595377246\n'
#             '    - -108.1725255364829\n'
#             '  - - 25.965597832728058\n'
#             '    - -108.17014157181615\n'
#             '  - - 25.955325751384514\n'
#             '    - -108.17387610939282\n'
#             '  - - 25.94304012072086\n'
#             '    - -108.18865977313799\n'
#             '  - - 25.943836425615753\n'
#             '    - -108.19387085308254\n'
#             '  - - 25.941100490669434\n'
#             '    - -108.20121517978241\n'
#             '  - - 25.932891668826745\n'
#             '    - -108.2083372026741\n'
#             '  - - 25.929675388134164\n'
#             '    - -108.20653096910767\n'
#             '  - - 25.925624552407548\n'
# ...
#             '    - -108.16392670022235\n'
#             '  - - 26.174758126117922\n'
#             '    - -108.16002153502534\n'
#             '  - - 26.181326186995758\n'
#             '    - -108.15499800276261\n'
#             '  - - 26.17724381715453\n'
#             '    - -108.14637142940119\n'
#             '  - - 26.176549372629886\n'
#             '    - -108.14080509116512\n'
#             '  - - 26.179485774305018\n'
#             '    - -108.13816660957308\n'
#             '  - - 26.179359362845442\n'
#             '    - -108.1360467898666\n'
#             '  - - 26.185778363181377\n'
#             '    - -108.13031979404644\n'
#             '  - - 26.184451187356494\n'
#             '    - -108.12605540254349\n'
#             '  - - 26.18134951608055\n'
#             '    - -108.12533376392001\n'
#             '  - - 26.186350466261217\n'
#             '    - -108.12014686106333\n'
#             '  - - 26.181758384566987\n'
#             '    - -108.11779341250752\n'
#             '  - - 26.17985035763047\n'
#             '    - -108.11386512222644\n'
#             '  - - 26.182113540858087\n'
#             '    - -108.11314856962149\n'
#             '  - - 26.186614205219996\n'
#             '    - -108.10527903601223\n'
#             '  - - 26.186305503097735\n'
#             '    - -108.0999348645838\n'
#             '  - - 26.18994753933816\n'
#             '    - -108.0961458028089\n'
#             '  - - 26.189147842430884\n'
#             '    - -108.0954986944564\n'
#             '  - - 26.182775230263637\n'
#             '    - -108.0936624177807\n'
#             '  - - 26.17559471515932\n'
#             '    - -108.09601878134714\n'
#             '  - - 26.16718074757085\n'
#             '    - -108.09540497111566\n'
#             '  - - 26.163980605936896\n'
#             '    - -108.09669661081135\n'
#             '  - - 26.158840022248626\n'
#             '    - -108.09514163815832\n'
#             '  - - 26.153847007096825\n'
#             '    - -108.09877092435238\n'
#             '  - - 26.14573495960593\n'
#             '    - -108.1007102824028\n'
#             '  - - 26.14419578901038\n'
#             '    - -108.1023714564419\n'
#             '  - - 26.13945315376878\n'
#             '    - -108.10043759141148\n'
#             '  - - 26.13689944248494\n'
#             '    - -108.10239010550968\n'
#             '  - - 26.130859267526258\n'
#             '    - -108.10065012918415\n'
#             '  - - 26.12913353325245\n'
#             '    - -108.0995357631329\n'
#             '  - - 26.129178495415875\n'
#             '    - -108.09713830241706\n'
#             '  - - 26.1224324148909\n'
#             '    - -108.0946383023285\n'
#             '  - - 26.12130265478373\n'
#             '    - -108.09224436762547\n'
#             '  - - 26.11665421688462\n'
#             '    - -108.09028615650652\n'
#             '  - - 26.115500109688917\n'
#             '    - -108.08821150296426\n'
#             '  - - 26.11652597541842\n'
#             '    - -108.08586076841827\n'
#             '  - - 26.11496815475504\n'
#             '    - -108.08466610707517\n'
#             '  - - 26.111708537904907\n'
#             '    - -108.08635060919909\n'
#             '  - - 26.107129816259196\n'
#             '    - -108.08265981378138\n'
#             '  - - 26.10571915813085\n'
#             '    - -108.08313487050843\n'
#             '  - - 26.106883709364517\n'
#             '    - -108.08635881522888\n'
#             '  - - 26.1047014984312\n'
#             '    - -108.08795942804784\n'
#             '  - - 26.104748902603546\n'
#             '    - -108.09187876729634\n'
#             '  - - 26.10260982382703\n'
#             '    - -108.0959825672155\n'
#             '  - - 26.099220202504277\n'
#             '    - -108.09465152637658\n'
#             '  - - 26.098748264788576\n'
#             '    - -108.09810442092936\n'
#             '  - - 26.096991198400872\n'
#             '    - -108.09903418930946\n'
#             '  - - 26.09361982014445\n'
#             '    - -108.09793759132286\n'
#             '  - - 26.08527143079436\n'
#             '    - -108.1002960578969\n'
#             '  - - 26.08349883435016\n'
#             '    - -108.0990763034626\n'
#             '  - - 26.07633900432102\n'
#             '    - -108.0996063603896\n'
#             '  - - 26.07275705429906\n'
#             '    - -108.09715410347455\n'
#             '  - - 26.07209699289944\n'
#             '    - -108.09443498758935\n'
#             '  - - 26.067616266610056\n'
#             '    - -108.09369707190672\n'
#             '  - - 26.065225315917864\n'
#             '    - -108.0912603450481\n'
#             '  - - 26.063558648858812\n'
#             '    - -108.0923714560875\n'
#             '  - - 26.063278225839383\n'
#             '    - -108.09763004220478\n'
#             '  - - 26.061392307983223\n'
#             '    - -108.0995994433644\n'
#             '  - - 26.056378811756918\n'
#             '    - -108.1006691862534\n'
#             '  - - 26.05390953278003\n'
#             '    - -108.10413469385207\n'
#             '  - - 26.05044497418481\n'
#             '    - -108.11466509013468\n'
#             '  - - 26.056120904819345\n'
#             '    - -108.11849891107231\n'
#             '  - - 26.05463374941285\n'
#             '    - -108.12466759949825\n'
#             '  - - 26.042541396451835\n'
#             '    - -108.12151940605314\n'
#             '  - - 26.035882596244154\n'
#             '    - -108.13438032680828\n'
#             '  - - 26.03420602814913\n'
#             '    - -108.13349314758301\n'
#             '  - - 26.02833966782231\n'
#             '    - -108.13546871976506\n'
#             '  - - 26.022105808159488\n'
#             '    - -108.13127940153502\n'
#             '  - - 26.01810508961511\n'
#             '    - -108.13071536948455\n'
#             '  - - 26.01052004704013\n'
#             '    - -108.13277754398142\n'
#             '  - - 26.01088090035199\n'
#             '    - -108.13502112813784\n'
#             '  - - 26.00860530607917\n'
#             '    - -108.13649058347998\n'
#             '  - - 26.01052140304506\n'
#             '    - -108.14293067389256\n'
#             '  - - 26.007430582808578\n'
#             '    - -108.14572004903316\n'
#             '  - - 26.01050309297846\n'
#             '    - -108.14971975057387\n'
#             '  - - 26.0053298891716\n'
#             '    - -108.1498690151165\n'
#             '  - - 26.000113960209426\n'
#             '    - -108.14701650374633\n'
#             '  - - 25.997489990670147\n'
#             '    - -108.14849362211635\n'
#             '  - - 25.997132189369374\n'
#             '    - -108.15073998728285\n'
#             '  - - 25.991488403851683\n'
#             '    - -108.15304216565225\n'
#             '  - - 25.987642442869966\n'
#             '    - -108.15241682637888\n'
#             '  - - 25.981936334125738\n'
#             '    - -108.15518049842608\n'
#             '  - - 25.980106364472984\n'
#             '    - -108.15325470342496\n'
#             '  - - 25.972169759619927\n'
#             '    - -108.15293759127212\n'
#             '  - - 25.96926082404467\n'
#             '    - -108.15114492175495\n'
#             '  - - 25.967735894500883\n'
#             '    - -108.15255781789146\n'
#             '  - - 25.971146063898342\n'
#             '    - -108.15631114053643\n'
#             '  - - 25.9698335371267\n'
#             '    - -108.15821855647071\n'
#             '  - - 25.97312333208657\n'
#             '    - -108.1602304117847\n'
#             '  - - 25.972019070072122\n'
#             '    - -108.1655015429476\n'
#             '  - - 25.96902651619285\n'
#             '    - -108.1685026418579\n'
#             '  - - 25.96918595377246\n'
#             '    - -108.1725255364829\n'
#             '  - - 25.965597832728058\n'
#             '    - -108.17014157181615\n'
#             '  - - 25.955325751384514\n'
#             '    - -108.17387610939282\n'
#             '  - - 25.94304012072086\n'
#             '    - -108.18865977313799\n'
#             '  - - 25.943836425615753\n'
#             '    - -108.19387085308254\n'
#             '  - - 25.941100490669434\n'
#             '    - -108.20121517978241\n'
#             '  - - 25.932891668826745\n'
#             '    - -108.2083372026741\n'
#             '  - - 25.929675388134164\n'
#             '    - -108.20653096910767\n'
#             '  - - 25.925624552407548\n'
#             '    - -108.21136698768872\n'
#             '  - - 25.916588907558996\n'
#             '    - -108.20821353922457\n'
#             '  - - 25.91066965003989\n'
#             '    - -108.21664988589441\n'
#             '  - - 25.895277737083514\n'
#             '    - -108.2216137399402\n'
#             '  - - 25.893011161843503\n'
#             '    - -108.22571286084228\n'
#             '  - - 25.88717226761656\n'
#             '    - -108.2265406328516\n'
#             '  - - 25.876869872162832\n'
#             '    - -108.23258745383446\n'
#             '  - - 25.87001772625222\n'
#             '    - -108.2340305620808\n'
#             '  - - 25.864955470848713\n'
#             '    - -108.23097361696743\n'
#             '  - - 25.854904676309673\n'
#             '    - -108.2304344390073\n'
#             '  - - 25.854361191333844\n'
#             '    - -108.23660533044125\n'
#             '  - - 25.845124130753046\n'
#             '    - -108.24610436797438\n'
#             '  - - 25.843913804353004\n'
#             '    - -108.24971225709065\n'
#             '  - - 25.844579154771843\n'
#             '    - -108.26218163842236\n'
#             '  - - 25.842852809495806\n'
#             '    - -108.26502841977168\n'
#             '  - - 25.838234753707123\n'
#             '    - -108.26599036726877\n'
#             '  - - 25.835805079874202\n'
#             '    - -108.26851922346229\n'
#             '  - - 25.833153645235083\n'
#             '    - -108.2910645254244\n'
#             '  - - 25.823158052896698\n'
#             '    - -108.2949596535849\n'
#             '  - - 25.813182331630507\n'
#             '    - -108.304425934999\n'
#             '  - - 25.80282893799136\n'
#             '    - -108.31925110389504\n'
#             '  - - 25.797967555318106\n'
#             '    - -108.32015174516926\n'
#             '  - - 25.78479610043405\n'
#             '    - -108.31876841714028\n'
#             '  - - 25.775974214362638\n'
#             '    - -108.32969069284756\n'
#             '  - - 25.76812794183797\n'
#             '    - -108.33000173397835\n'
#             '  - - 25.76577123927029\n'
#             '    - -108.33183306063601\n'
#             '  - - 25.75800560003881\n'
#             '    - -108.3426517449667\n'
#             '  - - 25.757733383049185\n'
#             '    - -108.35124786921737\n'
#             '  - - 25.764055134031533\n'
#             '    - -108.34645223478314\n'
#             '  - - 25.772901094190495\n'
#             '    - -108.3474435133869\n'
#             '  - - 25.781489080411568\n'
#             '    - -108.35942461294347\n'
#             '  - - 25.79807958872538\n'
#             '    - -108.36150686151335\n'
#             '  - - 25.835788939815526\n'
#             '    - -108.36043508461698\n'
#             '  - - 25.852188204434068\n'
#             '    - -108.35709073045875\n'
#             '  - - 25.86359262389419\n'
#             '    - -108.36015537360008\n'
#             '  - - 25.898479437723093\n'
#             '    - -108.36042952359672\n'
#             '  - - 25.91495560662127\n'
#             '    - -108.35904619556776\n'
#             '  - - 25.917733384719725\n'
#             '    - -108.35849063954805\n'
#             '  - - 25.919752767061016\n'
#             '    - -108.35530589297007\n'
#             '  - - 25.925825968139797\n'
#             '    - -108.35205950116801\n'
#             '  - - 25.941721828928276\n'
#             '    - -108.33266120564667\n'
#             '  - - 25.94384449564512\n'
#             '    - -108.33182397260299\n'
#             '  - - 25.947052843308875\n'
#             '    - -108.32409858351774\n'
#             '  - - 25.950549479020644\n'
#             '    - -108.32317424015734\n'
#             '  - - 25.953457533592704\n'
#             '    - -108.31939287441041\n'
#             '  - - 25.957498264282545\n'
#             '    - -108.31848022909259\n'
#             '  - - 25.960505602215555\n'
#             '    - -108.31265174490346\n'
#             '  - - 25.970682265212243\n'
#             '    - -108.31181481786085\n'
#             '  - - 25.9747982041755\n'
#             '    - -108.30980910056923\n'
#             '  - - 25.975880086108585\n'
#             '    - -108.30752289325784\n'
#             '  - - 25.98072085270689\n'
#             '    - -108.30654619470708\n'
#             '  - - 25.984727810273963\n'
#             '    - -108.30934808189316\n'
#             '  - - 25.989456611465236\n'
#             '    - -108.3102712382493\n'
#             '  - - 25.995920844965603\n'
#             '    - -108.30714423788123\n'
#             '  - - 26.003985623284617\n'
#             '    - -108.30766028975732\n'
#             '  - - 26.022204210517195\n'
#             '    - -108.30346859851868\n'
#             '  - - 26.029208062979308\n'
#             '    - -108.30401042148843\n'
#             '  - - 26.033600694948454\n'
#             '    - -108.30098239948022\n'
#             '  - - 26.033642674101085\n'
#             '    - -108.29626841734284\n'
#             '  - - 26.038252184858663\n'
#             '    - -108.30015805148336\n'
#             '  - - 26.041066583090235\n'
#             '    - -108.29792386036108\n'
#             '  - - 26.051346056460652\n'
#             '    - -108.29928606331333\n'
#             '  - - 26.053503513303948\n'
#             '    - -108.30153154647665\n'
#             '  - - 26.052869493999026\n'
#             '    - -108.30612674718223\n'
#             '  type: polygon\n'
#             "generation: '1'\n"
#             'levtype: sfc\n'
#             'model: IFS-FESOM\n'
#             'param: 167/260048/169\n'
#             "realization: '1'\n"
#             'resolution: high\n'
#             'stream: clte\n'
#             'time: '
#             '0000/0100/0200/0300/0400/0500/0600/0700/0800/0900/1000/1100/1200/1300/1400/1500/1600/1700/1800/1900/2000/2100/2200/2300\n'
#             'type: fc\n',
#  'verb': 'retrieve'}
# 2026-04-16 10:26:32 - INFO - Polytope user key found in session cache for user ewater-mmelotto
# Data is split up in parts
# Running 21 of 21
# start = '20140101'
# end = '20140731'
# 2026-04-16 10:26:32 - INFO - Request accepted. Please poll ./3922a35a-c801-4303-a404-d83d90a4652b for status
# 2026-04-16 10:26:32 - INFO - Polytope user key found in session cache for user ewater-mmelotto
# 2026-04-16 10:26:32 - INFO - Checking request status (3922a35a-c801-4303-a404-d83d90a4652b)...
# 2026-04-16 10:26:32 - INFO - The current status of the request is 'queued'
# 2026-04-16 10:26:54 - INFO - The current status of the request is 'processing'
# 2026-04-16 10:27:10 - INFO - The current status of the request is 'processed'
# 3922a35a-c801-4303-a404-d83d90a4652b.covjson:   0%|          | 0.00/4.91M [00:00<?, ?B/s]
# 3922a35a-c801-4303-a404-d83d90a4652b.covjson:  20%|██        | 1.00M/4.91M [00:00<00:01, 2.21MB/s]
# 3922a35a-c801-4303-a404-d83d90a4652b.covjson: 100%|██████████| 4.91M/4.91M [00:00<00:00, 10.4MB/s]
# Concatenating all windows...
# LumpedMakkinkForcing(start_time='1994-08-01T00:00:00Z', end_time='2014-07-31T00:00:00Z', directory=PosixPath('/project/ewater/Data/ewatercycleClimateImpact/HBV/forcing_data/mexico/hysets_10034/DestinE_historical'), shape=PosixPath('/project/ewater/Data/ewatercycleClimateImpact/HBV/forcing_data/mexico/hysets_10034/caravan/hysets_10034.shp'), filenames={'pr': '/project/ewater/Data/ewatercycleClimateImpact/HBV/forcing_data/mexico/hysets_10034/DestinE_historical/DestinE_historic_day_pr_1994_08_01-2014_07_31.nc', 'tas': '/project/ewater/Data/ewatercycleClimateImpact/HBV/forcing_data/mexico/hysets_10034/DestinE_historical/DestinE_historic_day_tas_1994_08_01-2014_07_31.nc', 'rsds': '/project/ewater/Data/ewatercycleClimateImpact/HBV/forcing_data/mexico/hysets_10034/DestinE_historical/DestinE_historic_day_rsds_1994_08_01-2014_07_31.nc', 'evspsblpot': '/project/ewater/Data/ewatercycleClimateImpact/HBV/forcing_data/mexico/hysets_10034/DestinE_historical/DestinE_historic_day_evspsblpot_1994_08_01-2014_07_31.nc'})
# CPU times: user 36.2 s, sys: 8.17 s, total: 44.4 s
# Wall time: 10min 46s

# %%
ds_DestinE_hist = xr.open_mfdataset([
    DestinE_hist_forcing_object["pr"],
    DestinE_hist_forcing_object["tas"],
    DestinE_hist_forcing_object["rsds"],
    DestinE_hist_forcing_object["evspsblpot"],
])

fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Subplot 1: precipitation + evspsblpot
ds_DestinE_hist["pr"].plot(ax=axes[0], label="precipitation")
ds_DestinE_hist["evspsblpot"].plot(ax=axes[0], label="evspsblpot")
axes[0].set_title("Precipitation & Evap")
axes[0].legend()

# Subplot 2: temperature
ds_DestinE_hist["tas"].plot(ax=axes[1], label="Temperature")
axes[1].set_title("Temperature")
axes[1].legend()

# Subplot 3: radiation
ds_DestinE_hist["rsds"].plot(ax=axes[2], label="Shortwave Radiation")
axes[2].set_title("Shortwave Radiation")
axes[2].legend()

plt.suptitle("DestinE CMIP6 historical (IFS-FESOM)")
plt.tight_layout()
plt.show()
